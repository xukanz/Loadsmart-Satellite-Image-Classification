# %%
# !pip install -q osmnx geopandas pyproj shapely fiona pyogrio

import os, math, time, random, shutil
import numpy as np
import pandas as pd
import geopandas as gpd
import requests
from pathlib import Path
from PIL import Image
import matplotlib.pyplot as plt

from sklearn.cluster import DBSCAN
from shapely.ops import unary_union
import osmnx as ox

# %%
# For the purpose of reproducibility
RANDOM_STATE = 42
random.seed(RANDOM_STATE)
np.random.seed(RANDOM_STATE)

# %% [markdown]
# Before running the below code: Upload the three KML files manually to `/content/` in your Colab session:
# *   `all_warehouses_cleaned_0.kml`
# *  `all_warehouses_cleaned_2000.kml`
# *   `all_warehouses_cleaned_4000.kml`

# %%
# Parse & deduplicate positive KML files
RAW_KML_FILES = [
    "all_warehouses_cleaned_0.kml",
    "all_warehouses_cleaned_2000.kml",
    "all_warehouses_cleaned_4000.kml",
]
BASE_DIR = "/content/kmls_cleaned"
os.makedirs(BASE_DIR, exist_ok=True)

def clean_kml_file(input_path: str, output_path: str) -> None:
    """Fix common XML/KML issues: BOM, leading whitespace, truncate to first valid tag."""
    with open(input_path, "r", encoding="utf-8-sig", errors="ignore") as f:
        text = f.read()
    text = text.lstrip()
    xml_idx, kml_idx = text.find("<?xml"), text.find("<kml")
    valid = [i for i in [xml_idx, kml_idx] if i != -1]
    if not valid:
        raise ValueError(f"No valid XML/KML start found in: {input_path}")
    text = text[min(valid):]
    with open(output_path, "w", encoding="utf-8") as f:
        f.write(text)

def batch_clean_kmls(raw_files):
    cleaned_files = []
    for i, fp in enumerate(raw_files):
        out_fp = os.path.join(BASE_DIR, f"warehouses_cleaned_{i}.kml")
        clean_kml_file(fp, out_fp)
        cleaned_files.append(out_fp)
        print(f"[clean] {fp} -> {out_fp}")
    return cleaned_files

def load_positive_points(cleaned_kml_files):
    gdf_list = []
    for fp in cleaned_kml_files:
        gdf_temp = gpd.read_file(fp, driver="KML")
        gdf_temp["source_file"] = Path(fp).name
        gdf_list.append(gdf_temp)
        print(f"[load] {fp}: rows = {len(gdf_temp)}")

    pos = pd.concat(gdf_list, ignore_index=True)
    pos = gpd.GeoDataFrame(pos, geometry="geometry", crs=gdf_list[0].crs)
    pos = pos[pos.geometry.notnull() & (pos.geometry.geom_type == "Point")].copy()
    pos["lon"], pos["lat"] = pos.geometry.x, pos.geometry.y
    pos = pos.dropna(subset=["lat", "lon"]).drop_duplicates(subset=["lat", "lon"]).reset_index(drop=True)
    pos["pos_id"] = pos.index.astype(str).str.zfill(7)
    print(f"[pos] unique cleaned point count = {len(pos)}")
    return pos

cleaned_kml_files = batch_clean_kmls(RAW_KML_FILES)
pos_gdf = load_positive_points(cleaned_kml_files)
pos_gdf[["pos_id", "lat", "lon", "source_file"]].to_csv(
    os.path.join(BASE_DIR, "positive_points_cleaned_dedup.csv"), index=False
)
print(pos_gdf.shape)
# Out:
# [clean] all_warehouses_cleaned_0.kml -> /content/kmls_cleaned/warehouses_cleaned_0.kml
# [clean] all_warehouses_cleaned_2000.kml -> /content/kmls_cleaned/warehouses_cleaned_1.kml
# [clean] all_warehouses_cleaned_4000.kml -> /content/kmls_cleaned/warehouses_cleaned_2.kml
# [load] /content/kmls_cleaned/warehouses_cleaned_0.kml: rows = 2000
# [load] /content/kmls_cleaned/warehouses_cleaned_1.kml: rows = 2000
# [load] /content/kmls_cleaned/warehouses_cleaned_2.kml: rows = 351
# [pos] unique cleaned point count = 4205
# (4205, 17)

# %%
# DBSCAN density labelling + parameter sweep
"""
Examined several DBSCAN parameter settings to assess whether local spatial
density patterns among positive warehouse locations were stable and interpretable.

eps=10 km / min_samples=5 provides the most balanced partition and is used as
the operational setting. Nearby settings serve as robustness checks.
"""
pos_geo = gpd.GeoDataFrame(
    pos_gdf[["pos_id", "lat", "lon"]].copy(),
    geometry=gpd.points_from_xy(pos_gdf["lon"], pos_gdf["lat"]),
    crs="EPSG:4326",
).to_crs(epsg=3857)
coords = np.column_stack([pos_geo.geometry.x, pos_geo.geometry.y])

def dbscan_summary(coords, eps_m, min_samples):
    labels = DBSCAN(eps=eps_m, min_samples=min_samples).fit_predict(coords)
    n_total = len(labels)
    n_noise = int(np.sum(labels == -1))
    non_noise = labels[labels != -1]
    n_clusters = len(set(non_noise)) if len(non_noise) > 0 else 0

    if n_clusters > 0:
        cluster_sizes = pd.Series(non_noise).value_counts().sort_values(ascending=False)
        largest_cluster = int(cluster_sizes.iloc[0])
        median_cluster_size = float(cluster_sizes.median())
        n_points_in_clusters = int((labels != -1).sum())
        prop_points_in_clusters = n_points_in_clusters / n_total
        n_clusters_ge_20 = int((cluster_sizes >= 20).sum())
        prop_points_in_large = cluster_sizes[cluster_sizes >= 20].sum() / n_total
    else:
        largest_cluster = median_cluster_size = n_points_in_clusters = 0
        prop_points_in_clusters = n_clusters_ge_20 = prop_points_in_large = 0.0

    return {
        "eps_km": eps_m / 1000, "min_samples": min_samples,
        "n_clusters": n_clusters, "n_noise": n_noise,
        "noise_prop": round(n_noise / n_total, 3),
        "largest_cluster": largest_cluster,
        "median_cluster_size": round(median_cluster_size, 1),
        "points_in_clusters": n_points_in_clusters,
        "prop_points_in_clusters": round(prop_points_in_clusters, 3),
        "n_clusters_ge_20": n_clusters_ge_20,
        "prop_points_in_large_clusters": round(prop_points_in_large, 3),
        "labels": labels,
    }

# --- Parameter sweep ---
eps_list_km = [7.5, 10, 15]
min_samples_list = [5, 8, 12]
sweep_results, labels_store = [], {}

for eps_km in eps_list_km:
    for ms in min_samples_list:
        out = dbscan_summary(coords, eps_m=eps_km * 1000, min_samples=ms)
        labels_store[(eps_km, ms)] = out["labels"]
        sweep_results.append({k: v for k, v in out.items() if k != "labels"})

sweep_df = pd.DataFrame(sweep_results).sort_values(["eps_km", "min_samples"]).reset_index(drop=True)
print("DBSCAN parameter sweep summary:")
print(sweep_df)
sweep_df.to_csv(os.path.join(BASE_DIR, "dbscan_parameter_sweep_summary.csv"), index=False)

# --- Apply chosen setting ---
CHOSEN_EPS_KM = 10
CHOSEN_MIN_SAMPLES = 5
chosen_labels = labels_store[(CHOSEN_EPS_KM, CHOSEN_MIN_SAMPLES)]

pos_dbscan = pos_geo.copy()
pos_dbscan["cluster_id"] = chosen_labels
cluster_size_map = (
    pos_dbscan[pos_dbscan["cluster_id"] != -1]
    .groupby("cluster_id").size().to_dict()
)
pos_dbscan["cluster_size"] = pos_dbscan["cluster_id"].map(cluster_size_map).fillna(0).astype(int)

def assign_density_type(row):
    if row["cluster_id"] == -1: return "isolated"
    if row["cluster_size"] >= 20: return "dense_cluster"
    return "small_cluster"

pos_dbscan["density_type"] = pos_dbscan.apply(assign_density_type, axis=1)
pos_dbscan = pos_dbscan.to_crs(epsg=4326)

pos_density = pos_dbscan[["pos_id", "lat", "lon", "cluster_id", "cluster_size", "density_type"]].copy()
print("\nChosen setting density label counts:")
print(pos_density["density_type"].value_counts())
print("\nSample density-labeled positives:")
print(pos_density.head())
pos_density.to_csv(os.path.join(BASE_DIR, "positive_points_density_labels.csv"), index=False)
# Out:
# DBSCAN parameter sweep summary:
#    eps_km  min_samples  n_clusters  n_noise  noise_prop  largest_cluster  \
# 0     7.5            5         161     2423       0.576               88
# 1     7.5            8          70     3089       0.735               59
# 2     7.5           12          31     3554       0.845               56
# 3    10.0            5         159     2070       0.492              113
# 4    10.0            8          86     2628       0.625              106
# 5    10.0           12          40     3210       0.763               93
# 6    15.0            5         156     1507       0.358              156
# 7    15.0            8          90     2045       0.486              143
# 8    15.0           12          49     2620       0.623              140
#
#    median_cluster_size  points_in_clusters  prop_points_in_clusters  \
# 0                  7.0                1782                    0.424
# 1                 11.5                1116                    0.265
# 2                 18.0                 651                    0.155
# 3                  8.0                2135                    0.508
# 4                 12.0                1577                    0.375
# 5                 18.5                 995                    0.237
# 6                  9.0                2698                    0.642
# 7                 13.0                2160                    0.514
# 8                 19.0                1585                    0.377
#
#    n_clusters_ge_20  prop_points_in_large_clusters
# 0                18                          0.155
# 1                15                          0.118
# 2                13                          0.091
# 3                23                          0.237
# 4                21                          0.205
# 5                18                          0.159
# 6                35                          0.403
# 7                32                          0.362
# 8                24                          0.286
#
# Chosen setting density label counts:
# density_type
# isolated         2070
# small_cluster    1138
# dense_cluster     997
# Name: count, dtype: int64
#
# Sample density-labeled positives:
#     pos_id        lat         lon  cluster_id  cluster_size   density_type
# 0  0000000  43.469939 -116.271908          -1             0       isolated
# 1  0000001  39.899337  -82.936869           0            32  dense_cluster
# 2  0000002  40.053882  -76.292253          45             9  small_cluster
# 3  0000003  42.054978  -87.798206          -1             0       isolated
# 4  0000004  49.171448 -122.670772          -1             0       isolated

# %%
# Density-aware negative sampling (mini strategy study)

# NOTE: density_v3_conservative is excluded from this study.
#
# v3 sets dense_cluster search_dist=1200m but exclusion_buffer=1800m,
# meaning the exclusion zone is larger than the search radius. In practice,
# nearly every candidate found within the search circle is immediately
# filtered out, yielding almost zero negatives for dense-cluster points.
# The sampler then exhausts all seed points without reaching n_target,
# making runtime unpredictably long with no meaningful output.
#
# The three remaining strategies form a clean progression:
#   baseline_global  — flat params across all density types (control)
#   density_v1 — moderate differentiation by density
#   density_v2 — aggressive differentiation by density

pos_gdf_with_density = pos_gdf.merge(
    pos_density[["pos_id", "density_type", "cluster_id", "cluster_size"]],
    on="pos_id", how="left"
)
print("Density label counts:")
print(pos_gdf_with_density["density_type"].value_counts(dropna=False))

# --- Strategy grid ---
DENSITY_STRATEGY_GRID = {
    "baseline_global": {
        "isolated":      {"search_dist": 2500, "exclusion_buffer": 1000},
        "small_cluster": {"search_dist": 2500, "exclusion_buffer": 1000},
        "dense_cluster": {"search_dist": 2500, "exclusion_buffer": 1000},
    },
    "density_v1": {
        "isolated":      {"search_dist": 4000, "exclusion_buffer": 900},
        "small_cluster": {"search_dist": 2500, "exclusion_buffer": 1100},
        "dense_cluster": {"search_dist": 1500, "exclusion_buffer": 1500},
    },
    "density_v2": {
        "isolated":      {"search_dist": 5000, "exclusion_buffer": 800},
        "small_cluster": {"search_dist": 3000, "exclusion_buffer": 1200},
        "dense_cluster": {"search_dist": 1800, "exclusion_buffer": 1600},
    },
}

# --- All 10 negative categories ---
NEGATIVE_CATEGORIES = {
    "fuel":         {"amenity": "fuel"},
    "parking":      {"amenity": "parking"},
    "restaurant":   {"amenity": "restaurant"},
    "hospital":     {"amenity": "hospital"},
    "hotel":        {"tourism": "hotel"},
    "supermarket":  {"shop": "supermarket"},
    "school":       {"amenity": "school"},
    "park":         {"leisure": "park"},
    "playground":   {"leisure": "playground"},
    "sports_centre":{"leisure": "sports_centre"},
}

# --- Seed allocation ---
SEED_ALLOC = {"isolated": 20, "small_cluster": 15, "dense_cluster": 15}

# --- Helper functions ---
def build_positive_exclusion_union(pos_gdf_wgs84, buffer_m=1000):
    pos_m = pos_gdf_wgs84.to_crs(epsg=3857)
    union = unary_union(pos_m.geometry.buffer(buffer_m))
    print(f"[buffer] built union buffer with {buffer_m}m")
    return union

def to_point_geometry(geom):
    if geom is None or getattr(geom, "is_empty", False): return None
    if geom.geom_type == "Point": return geom
    try:    return geom.representative_point()
    except Exception:
        try: return geom.centroid
        except Exception: return None

def collect_local_category_samples(
    pos_gdf, pos_buffer_union, tags, category_name,
    n_target=100, n_seed=20, search_dist=1200,
    oversample_factor=1.3, random_state=42,
):
    """
    Local sampling: sample seed positive points, query OSM, remove points
    within exclusion buffer, dedupe, and sample down to n_target.
    """
    t0 = time.time()
    if len(pos_gdf) == 0:
        return None, {"category": category_name, "candidates": 0, "seconds": 0.0}

    seed_points = pos_gdf.sample(n=min(n_seed, len(pos_gdf)), random_state=random_state).copy()
    collected, seen = [], set()
    target_collect = int(n_target * oversample_factor)

    for _, seed in seed_points.iterrows():
        center = (float(seed["lat"]), float(seed["lon"]))
        try:
            gdf_cat = ox.features_from_point(center, tags=tags, dist=search_dist)
        except Exception as e:
            print(f"[{category_name}] OSM query failed near {center}: {e}")
            continue

        if gdf_cat is None or len(gdf_cat) == 0: continue

        gdf_cat = gdf_cat.reset_index()
        gdf_cat = gdf_cat[gdf_cat.geometry.notnull()].copy()
        gdf_cat["geometry"] = gdf_cat["geometry"].apply(to_point_geometry)
        gdf_cat = gdf_cat[gdf_cat.geometry.notnull()].copy()
        if len(gdf_cat) == 0: continue

        gdf_cat = gpd.GeoDataFrame(gdf_cat, geometry="geometry", crs="EPSG:4326")
        gdf_cat["lon"] = gdf_cat.geometry.x
        gdf_cat["lat"] = gdf_cat.geometry.y
        gdf_cat = gdf_cat.dropna(subset=["lat", "lon"]).copy()

        gdf_cat_m = gdf_cat.to_crs(epsg=3857)
        gdf_cat_m = gdf_cat_m[~gdf_cat_m.geometry.within(pos_buffer_union)].copy()
        if len(gdf_cat_m) == 0: continue

        gdf_cat = gdf_cat_m.to_crs(epsg=4326)
        gdf_cat["neg_category"] = category_name
        gdf_cat["coord_key"] = gdf_cat.apply(
            lambda r: (round(float(r["lat"]), 6), round(float(r["lon"]), 6)), axis=1
        )
        gdf_cat = gdf_cat[~gdf_cat["coord_key"].isin(seen)].copy()
        seen.update(gdf_cat["coord_key"].tolist())
        if len(gdf_cat) == 0: continue

        collected.append(gdf_cat[["geometry", "lat", "lon", "neg_category"]].copy())
        current = sum(len(x) for x in collected)
        print(f"[{category_name}] candidates so far: {current}")
        if current >= target_collect: break

    if len(collected) == 0:
        elapsed = time.time() - t0
        print(f"[{category_name}] no candidates found. (time {elapsed:.1f}s)")
        return None, {"category": category_name, "candidates": 0, "seconds": elapsed}

    out = pd.concat(collected, ignore_index=True)
    out = gpd.GeoDataFrame(out, geometry="geometry", crs="EPSG:4326")
    out = out.drop_duplicates(subset=["lat", "lon"]).copy()
    out = out.sample(n=min(n_target, len(out)), random_state=random_state).reset_index(drop=True)

    elapsed = time.time() - t0
    print(f"[{category_name}] final kept: {len(out)} (time {elapsed:.1f}s)")
    return out, {"category": category_name, "candidates": len(out), "seconds": elapsed}

def collect_local_category_samples_by_density(
    pos_gdf_with_density, tags, category_name, density_strategy,
    n_target=100, seed_alloc=None, oversample_factor=1.08, random_state=42,
):
    t0 = time.time()
    if seed_alloc is None:
        seed_alloc = {"isolated": 20, "small_cluster": 15, "dense_cluster": 15}

    density_types = ["isolated", "small_cluster", "dense_cluster"]
    collected_parts, diagnostics = [], []
    planned_total_seed = sum(seed_alloc.values())

    for density_type in density_types:
        pos_subset = pos_gdf_with_density[pos_gdf_with_density["density_type"] == density_type].copy()
        params = density_strategy[density_type]
        search_dist = params["search_dist"]
        exclusion_buffer = params["exclusion_buffer"]
        n_seed = min(seed_alloc.get(density_type, 0), len(pos_subset))

        diag_base = {
            "category": category_name, "density_type": density_type,
            "n_pos_available": len(pos_subset), "n_seed_used": n_seed,
            "search_dist": search_dist, "exclusion_buffer": exclusion_buffer,
        }

        if len(pos_subset) == 0 or n_seed == 0:
            diagnostics.append({**diag_base, "n_candidates_kept": 0})
            continue

        pos_buffer_union = build_positive_exclusion_union(pos_gdf_with_density, buffer_m=exclusion_buffer)
        density_target = max(1, int(round(n_target * (n_seed / planned_total_seed))))

        neg_part, _ = collect_local_category_samples(
            pos_gdf=pos_subset, pos_buffer_union=pos_buffer_union, tags=tags,
            category_name=f"{category_name}__{density_type}",
            n_target=density_target, n_seed=n_seed,
            search_dist=search_dist, oversample_factor=oversample_factor,
            random_state=random_state,
        )

        n_kept = 0
        if neg_part is not None and len(neg_part) > 0:
            neg_part = neg_part.copy()
            neg_part["seed_density_type"] = density_type
            neg_part["search_dist_used"] = search_dist
            neg_part["exclusion_buffer_used"] = exclusion_buffer
            neg_part["base_category"] = category_name
            neg_part["neg_category"] = category_name
            collected_parts.append(neg_part)
            n_kept = len(neg_part)

        diagnostics.append({**diag_base, "n_candidates_kept": n_kept})

    if len(collected_parts) == 0:
        elapsed = time.time() - t0
        return None, {"category": category_name, "seconds": elapsed, "final_kept": 0,
                      "diagnostics_df": pd.DataFrame(diagnostics)}

    out = pd.concat(collected_parts, ignore_index=True)
    out = gpd.GeoDataFrame(out, geometry="geometry", crs="EPSG:4326")
    out["coord_key"] = out.apply(
        lambda r: (round(float(r["lat"]), 6), round(float(r["lon"]), 6)), axis=1
    )
    out = out.drop_duplicates(subset=["coord_key"]).drop(columns=["coord_key"])
    if len(out) > n_target:
        out = out.sample(n=n_target, random_state=random_state).copy()
    out = out.reset_index(drop=True)

    elapsed = time.time() - t0
    return out, {"category": category_name, "seconds": elapsed, "final_kept": len(out),
                 "diagnostics_df": pd.DataFrame(diagnostics)}

def run_density_strategy_mini_study(
    pos_gdf_with_density, negative_categories, strategy_grid,
    n_target_per_category=100, seed_alloc=None,
    oversample_factor=1.08, random_state=42,
):
    all_strategy_results = {}
    strategy_summary_rows, strategy_diag_rows = [], []

    for strategy_name, density_strategy in strategy_grid.items():
        print("\n" + "=" * 70)
        print(f"Running strategy: {strategy_name}")
        print("=" * 70)

        all_negs, per_cat_rows = [], []

        for cat, tags in negative_categories.items():
            print(f"\n[strategy={strategy_name}] category={cat}")
            neg_cat_gdf, out = collect_local_category_samples_by_density(
                pos_gdf_with_density=pos_gdf_with_density, tags=tags,
                category_name=cat, density_strategy=density_strategy,
                n_target=n_target_per_category, seed_alloc=seed_alloc,
                oversample_factor=oversample_factor, random_state=random_state,
            )

            diag_df = out["diagnostics_df"].copy()
            diag_df["strategy_name"] = strategy_name
            diag_df["category_total_final_kept"] = out["final_kept"]
            diag_df["category_seconds"] = out["seconds"]
            strategy_diag_rows.append(diag_df)

            per_cat_rows.append({
                "strategy_name": strategy_name, "category": cat,
                "final_kept": out["final_kept"], "seconds": out["seconds"],
            })

            if neg_cat_gdf is not None and len(neg_cat_gdf) > 0:
                neg_cat_gdf = neg_cat_gdf.copy()
                neg_cat_gdf["strategy_name"] = strategy_name
                all_negs.append(neg_cat_gdf)

        per_cat_df = pd.DataFrame(per_cat_rows)

        if len(all_negs) > 0:
            neg_gdf = gpd.GeoDataFrame(
                pd.concat(all_negs, ignore_index=True),
                geometry="geometry", crs="EPSG:4326"
            ).reset_index(drop=True)
            neg_gdf["sample_id"] = neg_gdf.index.astype(str).str.zfill(7)
            neg_gdf["image_name"] = "neg_" + neg_gdf["sample_id"] + ".png"
        else:
            neg_gdf = None

        total_final = 0 if neg_gdf is None else len(neg_gdf)
        strategy_summary_rows.append({
            "strategy_name": strategy_name,
            "n_categories": len(per_cat_df),
            "total_final_negatives": total_final,
            "mean_per_category": per_cat_df["final_kept"].mean() if len(per_cat_df) else 0,
            "median_per_category": per_cat_df["final_kept"].median() if len(per_cat_df) else 0,
            "total_runtime_sec": per_cat_df["seconds"].sum() if len(per_cat_df) else 0,
        })
        all_strategy_results[strategy_name] = {
            "neg_gdf": neg_gdf,
            "per_category_summary": per_cat_df,
        }

    strategy_summary_df = pd.DataFrame(strategy_summary_rows)
    strategy_diag_df = pd.concat(strategy_diag_rows, ignore_index=True)
    return all_strategy_results, strategy_summary_df, strategy_diag_df

# --- Run mini study ---
all_strategy_results, strategy_summary_df, strategy_diag_df = run_density_strategy_mini_study(
    pos_gdf_with_density=pos_gdf_with_density,
    negative_categories=NEGATIVE_CATEGORIES,
    strategy_grid=DENSITY_STRATEGY_GRID,
    n_target_per_category=100,
    seed_alloc=SEED_ALLOC,
    oversample_factor=1.08,
    random_state=42,
)

print("\n=== Strategy summary ===")
print(strategy_summary_df.sort_values("total_final_negatives", ascending=False))
print("\n=== Diagnostics sample ===")
print(strategy_diag_df.head(20))
# Out:
# Density label counts:
# density_type
# isolated         2070
# small_cluster    1138
# dense_cluster     997
# Name: count, dtype: int64
#
# ======================================================================
# Running strategy: baseline_global
# ======================================================================
#
# [strategy=baseline_global] category=fuel
# [buffer] built union buffer with 1000m
# [fuel__isolated] candidates so far: 12
# [fuel__isolated] candidates so far: 14
# [fuel__isolated] candidates so far: 16
# [fuel__isolated] candidates so far: 19
# [fuel__isolated] candidates so far: 21
# [fuel__isolated] candidates so far: 26
# [fuel__isolated] candidates so far: 31
# [fuel__isolated] candidates so far: 40
# [fuel__isolated] candidates so far: 43
# [fuel__isolated] final kept: 40 (time 16.6s)
# [buffer] built union buffer with 1000m
# [fuel__small_cluster] candidates so far: 6
# [fuel__small_cluster] candidates so far: 8
# [fuel__small_cluster] candidates so far: 12
# [fuel__small_cluster] candidates so far: 16
# [fuel__small_cluster] candidates so far: 24
# [fuel__small_cluster] candidates so far: 25
# [fuel__small_cluster] candidates so far: 27
# [fuel__small_cluster] candidates so far: 32
# [fuel__small_cluster] final kept: 30 (time 17.9s)
# [buffer] built union buffer with 1000m
# [fuel__dense_cluster] candidates so far: 8
# [fuel__dense_cluster] candidates so far: 10
# [fuel__dense_cluster] candidates so far: 17
# [fuel__dense_cluster] candidates so far: 29
# [fuel__dense_cluster] candidates so far: 44
# [fuel__dense_cluster] final kept: 30 (time 19.4s)
#
# [strategy=baseline_global] category=parking
# [buffer] built union buffer with 1000m
# [parking__isolated] candidates so far: 179
# [parking__isolated] final kept: 40 (time 3.4s)
# [buffer] built union buffer with 1000m
# [parking__small_cluster] candidates so far: 218
# [parking__small_cluster] final kept: 30 (time 4.9s)
# [buffer] built union buffer with 1000m
# [parking__dense_cluster] candidates so far: 410
# [parking__dense_cluster] final kept: 30 (time 2.3s)
#
# [strategy=baseline_global] category=restaurant
# [buffer] built union buffer with 1000m
# [restaurant__isolated] candidates so far: 16
# [restaurant__isolated] OSM query failed near (29.4232747, -98.5972939): No matching features. Check query location, tags, and log.
# [restaurant__isolated] candidates so far: 31
# [restaurant__isolated] candidates so far: 32
# [restaurant__isolated] candidates so far: 99
# [restaurant__isolated] final kept: 40 (time 11.3s)
# [buffer] built union buffer with 1000m
# [restaurant__small_cluster] candidates so far: 13
# [restaurant__small_cluster] OSM query failed near (40.0129752, -76.71924779999999): No matching features. Check query location, tags, and log.
# [restaurant__small_cluster] candidates so far: 29
# [restaurant__small_cluster] candidates so far: 44
# [restaurant__small_cluster] final kept: 30 (time 7.8s)
# [buffer] built union buffer with 1000m
# [restaurant__dense_cluster] candidates so far: 68
# [restaurant__dense_cluster] final kept: 30 (time 5.2s)
#
# [strategy=baseline_global] category=hospital
# [buffer] built union buffer with 1000m
# [hospital__isolated] candidates so far: 1
# [hospital__isolated] candidates so far: 2
# [hospital__isolated] candidates so far: 3
# [hospital__isolated] OSM query failed near (42.1127167, -71.4708436): No matching features. Check query location, tags, and log.
# [hospital__isolated] candidates so far: 4
# [hospital__isolated] OSM query failed near (32.4481943, -93.7748094): No matching features. Check query location, tags, and log.
# [hospital__isolated] OSM query failed near (52.5278899, -0.300448): No matching features. Check query location, tags, and log.
# [hospital__isolated] OSM query failed near (35.9583737, -84.14550260000001): No matching features. Check query location, tags, and log.
# [hospital__isolated] OSM query failed near (42.4909924, -92.3219282): No matching features. Check query location, tags, and log.
# [hospital__isolated] OSM query failed near (28.7145622, -81.59405509999999): No matching features. Check query location, tags, and log.
# [hospital__isolated] candidates so far: 5
# [hospital__isolated] OSM query failed near (38.944189, -95.019476): No matching features. Check query location, tags, and log.
# [hospital__isolated] candidates so far: 9
# [hospital__isolated] OSM query failed near (33.3336995, -87.0154424): No matching features. Check query location, tags, and log.
# [hospital__isolated] OSM query failed near (42.0850507, -71.4600414): No matching features. Check query location, tags, and log.
# [hospital__isolated] candidates so far: 10
# [hospital__isolated] OSM query failed near (25.9549931, -97.4076254): No matching features. Check query location, tags, and log.
# [hospital__isolated] OSM query failed near (40.2060266, -79.62065919999999): No matching features. Check query location, tags, and log.
# [hospital__isolated] OSM query failed near (35.8187957, -80.97943339999999): No matching features. Check query location, tags, and log.
# [hospital__isolated] OSM query failed near (35.5868669, -80.8064361): No matching features. Check query location, tags, and log.
# [hospital__isolated] final kept: 10 (time 46.1s)
# [buffer] built union buffer with 1000m
# [hospital__small_cluster] OSM query failed near (35.4212494, -80.6631755): No matching features. Check query location, tags, and log.
# [hospital__small_cluster] OSM query failed near (40.0129752, -76.71924779999999): No matching features. Check query location, tags, and log.
# [hospital__small_cluster] OSM query failed near (47.2085859, -122.241051): No matching features. Check query location, tags, and log.
# [hospital__small_cluster] OSM query failed near (40.0483977, -76.3886708): No matching features. Check query location, tags, and log.
# [hospital__small_cluster] candidates so far: 1
# [hospital__small_cluster] OSM query failed near (41.2881194, -75.7422504): No matching features. Check query location, tags, and log.
# [hospital__small_cluster] candidates so far: 2
# [hospital__small_cluster] OSM query failed near (37.9997937, -122.3369357): No matching features. Check query location, tags, and log.
# [hospital__small_cluster] OSM query failed near (29.8043645, -95.27087879999999): No matching features. Check query location, tags, and log.
# [hospital__small_cluster] candidates so far: 8
# [hospital__small_cluster] candidates so far: 12
# [hospital__small_cluster] OSM query failed near (40.8605866, -74.3038603): No matching features. Check query location, tags, and log.
# [hospital__small_cluster] OSM query failed near (33.2790678, -111.8087505): No matching features. Check query location, tags, and log.
# [hospital__small_cluster] OSM query failed near (38.88692, -77.006344): No matching features. Check query location, tags, and log.
# [hospital__small_cluster] OSM query failed near (36.004783, -86.58301180000001): No matching features. Check query location, tags, and log.
# [hospital__small_cluster] final kept: 12 (time 28.7s)
# [buffer] built union buffer with 1000m
# [hospital__dense_cluster] OSM query failed near (43.8034093, -79.52085939999999): No matching features. Check query location, tags, and log.
# [hospital__dense_cluster] OSM query failed near (32.790974, -97.01603999999999): No matching features. Check query location, tags, and log.
# [hospital__dense_cluster] OSM query failed near (35.0287559, -89.9212184): No matching features. Check query location, tags, and log.
# [hospital__dense_cluster] OSM query failed near (32.9305457, -96.8348939): No matching features. Check query location, tags, and log.
# [hospital__dense_cluster] candidates so far: 3
# [hospital__dense_cluster] candidates so far: 4
# [hospital__dense_cluster] OSM query failed near (33.9025764, -117.2853348): No matching features. Check query location, tags, and log.
# [hospital__dense_cluster] OSM query failed near (40.72913399999999, -111.9821665): No matching features. Check query location, tags, and log.
# [hospital__dense_cluster] OSM query failed near (39.78579269999999, -82.9367113): No matching features. Check query location, tags, and log.
# [hospital__dense_cluster] candidates so far: 6
# [hospital__dense_cluster] OSM query failed near (29.7798592, -95.43929829999999): No matching features. Check query location, tags, and log.
# [hospital__dense_cluster] OSM query failed near (33.9923262, -118.1594227): No matching features. Check query location, tags, and log.
# [hospital__dense_cluster] OSM query failed near (34.9260993, -90.0028931): No matching features. Check query location, tags, and log.
# [hospital__dense_cluster] OSM query failed near (32.8033265, -97.4358585): No matching features. Check query location, tags, and log.
# [hospital__dense_cluster] candidates so far: 8
# [hospital__dense_cluster] final kept: 8 (time 25.3s)
#
# [strategy=baseline_global] category=hotel
# [buffer] built union buffer with 1000m
# [hotel__isolated] candidates so far: 7
# [hotel__isolated] candidates so far: 9
# [hotel__isolated] OSM query failed near (42.1127167, -71.4708436): No matching features. Check query location, tags, and log.
# [hotel__isolated] candidates so far: 15
# [hotel__isolated] OSM query failed near (32.4481943, -93.7748094): No matching features. Check query location, tags, and log.
# [hotel__isolated] candidates so far: 19
# [hotel__isolated] OSM query failed near (35.9583737, -84.14550260000001): No matching features. Check query location, tags, and log.
# [hotel__isolated] candidates so far: 22
# [hotel__isolated] OSM query failed near (28.7145622, -81.59405509999999): No matching features. Check query location, tags, and log.
# [hotel__isolated] OSM query failed near (41.5558675, -89.10088689999999): No matching features. Check query location, tags, and log.
# [hotel__isolated] OSM query failed near (38.944189, -95.019476): No matching features. Check query location, tags, and log.
# [hotel__isolated] candidates so far: 23
# [hotel__isolated] candidates so far: 24
# [hotel__isolated] OSM query failed near (43.2436779, -81.1363248): No matching features. Check query location, tags, and log.
# [hotel__isolated] candidates so far: 25
# [hotel__isolated] candidates so far: 29
# [hotel__isolated] OSM query failed near (35.8187957, -80.97943339999999): No matching features. Check query location, tags, and log.
# [hotel__isolated] OSM query failed near (35.5868669, -80.8064361): No matching features. Check query location, tags, and log.
# [hotel__isolated] final kept: 29 (time 50.5s)
# [buffer] built union buffer with 1000m
# [hotel__small_cluster] candidates so far: 1
# [hotel__small_cluster] candidates so far: 2
# [hotel__small_cluster] OSM query failed near (47.2085859, -122.241051): No matching features. Check query location, tags, and log.
# [hotel__small_cluster] candidates so far: 5
# [hotel__small_cluster] candidates so far: 28
# [hotel__small_cluster] OSM query failed near (41.2881194, -75.7422504): No matching features. Check query location, tags, and log.
# [hotel__small_cluster] candidates so far: 30
# [hotel__small_cluster] candidates so far: 32
# [hotel__small_cluster] final kept: 30 (time 17.9s)
# [buffer] built union buffer with 1000m
# [hotel__dense_cluster] candidates so far: 7
# [hotel__dense_cluster] OSM query failed near (32.790974, -97.01603999999999): No matching features. Check query location, tags, and log.
# [hotel__dense_cluster] OSM query failed near (35.0287559, -89.9212184): No matching features. Check query location, tags, and log.
# [hotel__dense_cluster] candidates so far: 27
# [hotel__dense_cluster] candidates so far: 62
# [hotel__dense_cluster] final kept: 30 (time 13.0s)
#
# [strategy=baseline_global] category=supermarket
# [buffer] built union buffer with 1000m
# [supermarket__isolated] candidates so far: 5
# [supermarket__isolated] OSM query failed near (29.4232747, -98.5972939): No matching features. Check query location, tags, and log.
# [supermarket__isolated] candidates so far: 6
# [supermarket__isolated] candidates so far: 9
# [supermarket__isolated] candidates so far: 17
# [supermarket__isolated] candidates so far: 21
# [supermarket__isolated] OSM query failed near (35.9583737, -84.14550260000001): No matching features. Check query location, tags, and log.
# [supermarket__isolated] candidates so far: 33
# [supermarket__isolated] OSM query failed near (28.7145622, -81.59405509999999): No matching features. Check query location, tags, and log.
# [supermarket__isolated] candidates so far: 34
# [supermarket__isolated] OSM query failed near (38.944189, -95.019476): No matching features. Check query location, tags, and log.
# [supermarket__isolated] candidates so far: 36
# [supermarket__isolated] candidates so far: 38
# [supermarket__isolated] candidates so far: 40
# [supermarket__isolated] OSM query failed near (25.9549931, -97.4076254): No matching features. Check query location, tags, and log.
# [supermarket__isolated] OSM query failed near (40.2060266, -79.62065919999999): No matching features. Check query location, tags, and log.
# [supermarket__isolated] OSM query failed near (35.8187957, -80.97943339999999): No matching features. Check query location, tags, and log.
# [supermarket__isolated] candidates so far: 43
# [supermarket__isolated] final kept: 40 (time 65.3s)
# [buffer] built union buffer with 1000m
# [supermarket__small_cluster] candidates so far: 3
# [supermarket__small_cluster] OSM query failed near (40.0129752, -76.71924779999999): No matching features. Check query location, tags, and log.
# [supermarket__small_cluster] candidates so far: 4
# [supermarket__small_cluster] candidates so far: 7
# [supermarket__small_cluster] candidates so far: 9
# [supermarket__small_cluster] OSM query failed near (41.2881194, -75.7422504): No matching features. Check query location, tags, and log.
# [supermarket__small_cluster] OSM query failed near (29.705843, -95.086879): No matching features. Check query location, tags, and log.
# [supermarket__small_cluster] candidates so far: 10
# [supermarket__small_cluster] OSM query failed near (29.8043645, -95.27087879999999): No matching features. Check query location, tags, and log.
# [supermarket__small_cluster] candidates so far: 33
# [supermarket__small_cluster] final kept: 30 (time 87.7s)
# [buffer] built union buffer with 1000m
# [supermarket__dense_cluster] candidates so far: 7
# [supermarket__dense_cluster] OSM query failed near (32.790974, -97.01603999999999): No matching features. Check query location, tags, and log.
# [supermarket__dense_cluster] OSM query failed near (35.0287559, -89.9212184): No matching features. Check query location, tags, and log.
# [supermarket__dense_cluster] candidates so far: 16
# [supermarket__dense_cluster] candidates so far: 25
# [supermarket__dense_cluster] candidates so far: 27
# [supermarket__dense_cluster] OSM query failed near (33.9025764, -117.2853348): No matching features. Check query location, tags, and log.
# [supermarket__dense_cluster] OSM query failed near (40.72913399999999, -111.9821665): No matching features. Check query location, tags, and log.
# [supermarket__dense_cluster] OSM query failed near (39.78579269999999, -82.9367113): No matching features. Check query location, tags, and log.
# [supermarket__dense_cluster] candidates so far: 28
# [supermarket__dense_cluster] candidates so far: 29
# [supermarket__dense_cluster] candidates so far: 30
# [supermarket__dense_cluster] OSM query failed near (34.9260993, -90.0028931): No matching features. Check query location, tags, and log.
# [supermarket__dense_cluster] candidates so far: 34
# [supermarket__dense_cluster] final kept: 30 (time 107.7s)
#
# [strategy=baseline_global] category=school
# [buffer] built union buffer with 1000m
# [school__isolated] candidates so far: 12
# [school__isolated] candidates so far: 25
# [school__isolated] candidates so far: 45
# [school__isolated] final kept: 40 (time 15.7s)
# [buffer] built union buffer with 1000m
# [school__small_cluster] candidates so far: 5
# [school__small_cluster] candidates so far: 10
# [school__small_cluster] candidates so far: 17
# [school__small_cluster] candidates so far: 21
# [school__small_cluster] candidates so far: 31
# [school__small_cluster] candidates so far: 32
# [school__small_cluster] final kept: 30 (time 97.6s)
# [buffer] built union buffer with 1000m
# [school__dense_cluster] OSM query failed near (43.8034093, -79.52085939999999): No matching features. Check query location, tags, and log.
# [school__dense_cluster] candidates so far: 1
# [school__dense_cluster] candidates so far: 2
# [school__dense_cluster] candidates so far: 15
# [school__dense_cluster] candidates so far: 47
# [school__dense_cluster] final kept: 30 (time 9.7s)
#
# [strategy=baseline_global] category=park
# [buffer] built union buffer with 1000m
# [park__isolated] candidates so far: 1
# [park__isolated] candidates so far: 15
# [park__isolated] candidates so far: 28
# [park__isolated] OSM query failed near (42.1127167, -71.4708436): No matching features. Check query location, tags, and log.
# [park__isolated] candidates so far: 75
# [park__isolated] final kept: 40 (time 9.6s)
# [buffer] built union buffer with 1000m
# [park__small_cluster] candidates so far: 7
# [park__small_cluster] candidates so far: 11
# [park__small_cluster] candidates so far: 20
# [park__small_cluster] candidates so far: 26
# [park__small_cluster] candidates so far: 34
# [park__small_cluster] final kept: 30 (time 13.0s)
# [buffer] built union buffer with 1000m
# [park__dense_cluster] candidates so far: 3
# [park__dense_cluster] candidates so far: 5
# [park__dense_cluster] candidates so far: 7
# [park__dense_cluster] candidates so far: 28
# [park__dense_cluster] candidates so far: 77
# [park__dense_cluster] final kept: 30 (time 88.4s)
#
# [strategy=baseline_global] category=playground
# [buffer] built union buffer with 1000m
# [playground__isolated] candidates so far: 5
# [playground__isolated] candidates so far: 25
# [playground__isolated] candidates so far: 40
# [playground__isolated] candidates so far: 42
# [playground__isolated] candidates so far: 103
# [playground__isolated] final kept: 40 (time 25.7s)
# [buffer] built union buffer with 1000m
# [playground__small_cluster] candidates so far: 20
# [playground__small_cluster] candidates so far: 29
# [playground__small_cluster] candidates so far: 59
# [playground__small_cluster] final kept: 30 (time 12.7s)
# [buffer] built union buffer with 1000m
# [playground__dense_cluster] candidates so far: 4
# [playground__dense_cluster] candidates so far: 7
# [playground__dense_cluster] OSM query failed near (35.0287559, -89.9212184): No matching features. Check query location, tags, and log.
# [playground__dense_cluster] candidates so far: 22
# [playground__dense_cluster] candidates so far: 114
# [playground__dense_cluster] final kept: 30 (time 78.9s)
#
# [strategy=baseline_global] category=sports_centre
# [buffer] built union buffer with 1000m
# [sports_centre__isolated] candidates so far: 4
# [sports_centre__isolated] candidates so far: 5
# [sports_centre__isolated] candidates so far: 7
# [sports_centre__isolated] OSM query failed near (42.1127167, -71.4708436): No matching features. Check query location, tags, and log.
# [sports_centre__isolated] candidates so far: 11
# [sports_centre__isolated] candidates so far: 12
# [sports_centre__isolated] candidates so far: 13
# [sports_centre__isolated] candidates so far: 17
# [sports_centre__isolated] candidates so far: 18
# [sports_centre__isolated] OSM query failed near (28.7145622, -81.59405509999999): No matching features. Check query location, tags, and log.
# [sports_centre__isolated] OSM query failed near (41.5558675, -89.10088689999999): No matching features. Check query location, tags, and log.
# [sports_centre__isolated] OSM query failed near (38.944189, -95.019476): No matching features. Check query location, tags, and log.
# [sports_centre__isolated] candidates so far: 19
# [sports_centre__isolated] OSM query failed near (33.3336995, -87.0154424): No matching features. Check query location, tags, and log.
# [sports_centre__isolated] candidates so far: 20
# [sports_centre__isolated] OSM query failed near (25.9549931, -97.4076254): No matching features. Check query location, tags, and log.
# [sports_centre__isolated] OSM query failed near (40.2060266, -79.62065919999999): No matching features. Check query location, tags, and log.
# [sports_centre__isolated] OSM query failed near (35.8187957, -80.97943339999999): No matching features. Check query location, tags, and log.
# [sports_centre__isolated] OSM query failed near (35.5868669, -80.8064361): No matching features. Check query location, tags, and log.
# [sports_centre__isolated] final kept: 20 (time 37.2s)
# [buffer] built union buffer with 1000m
# [sports_centre__small_cluster] candidates so far: 3
# [sports_centre__small_cluster] candidates so far: 4
# [sports_centre__small_cluster] candidates so far: 8
# [sports_centre__small_cluster] candidates so far: 10
# [sports_centre__small_cluster] candidates so far: 11
# [sports_centre__small_cluster] OSM query failed near (41.2881194, -75.7422504): No matching features. Check query location, tags, and log.
# [sports_centre__small_cluster] OSM query failed near (29.705843, -95.086879): No matching features. Check query location, tags, and log.
# [sports_centre__small_cluster] candidates so far: 14
# [sports_centre__small_cluster] candidates so far: 17
# [sports_centre__small_cluster] candidates so far: 41
# [sports_centre__small_cluster] final kept: 30 (time 31.8s)
# [buffer] built union buffer with 1000m
# [sports_centre__dense_cluster] candidates so far: 8
# [sports_centre__dense_cluster] OSM query failed near (32.790974, -97.01603999999999): No matching features. Check query location, tags, and log.
# [sports_centre__dense_cluster] OSM query failed near (35.0287559, -89.9212184): No matching features. Check query location, tags, and log.
# [sports_centre__dense_cluster] candidates so far: 15
# [sports_centre__dense_cluster] candidates so far: 32
# [sports_centre__dense_cluster] final kept: 30 (time 80.2s)
#
# ======================================================================
# Running strategy: density_v1
# ======================================================================
#
# [strategy=density_v1] category=fuel
# [buffer] built union buffer with 900m
# [fuel__isolated] candidates so far: 18
# [fuel__isolated] candidates so far: 30
# [fuel__isolated] candidates so far: 37
# [fuel__isolated] candidates so far: 42
# [fuel__isolated] candidates so far: 61
# [fuel__isolated] final kept: 40 (time 8.5s)
# [buffer] built union buffer with 1100m
# [fuel__small_cluster] candidates so far: 5
# [fuel__small_cluster] candidates so far: 7
# [fuel__small_cluster] candidates so far: 11
# [fuel__small_cluster] candidates so far: 14
# [fuel__small_cluster] candidates so far: 21
# [fuel__small_cluster] candidates so far: 23
# [fuel__small_cluster] candidates so far: 28
# [fuel__small_cluster] candidates so far: 33
# [fuel__small_cluster] final kept: 30 (time 3.6s)
# [buffer] built union buffer with 1500m
# [fuel__dense_cluster] candidates so far: 2
# [fuel__dense_cluster] candidates so far: 8
# [fuel__dense_cluster] candidates so far: 10
# [fuel__dense_cluster] candidates so far: 12
# [fuel__dense_cluster] OSM query failed near (39.78579269999999, -82.9367113): No matching features. Check query location, tags, and log.
# [fuel__dense_cluster] candidates so far: 15
# [fuel__dense_cluster] candidates so far: 18
# [fuel__dense_cluster] candidates so far: 20
# [fuel__dense_cluster] final kept: 20 (time 33.6s)
#
# [strategy=density_v1] category=parking
# [buffer] built union buffer with 900m
# [parking__isolated] candidates so far: 259
# [parking__isolated] final kept: 40 (time 2.6s)
# [buffer] built union buffer with 1100m
# [parking__small_cluster] candidates so far: 204
# [parking__small_cluster] final kept: 30 (time 0.2s)
# [buffer] built union buffer with 1500m
# [parking__dense_cluster] candidates so far: 96
# [parking__dense_cluster] final kept: 30 (time 2.1s)
#
# [strategy=density_v1] category=restaurant
# [buffer] built union buffer with 900m
# [restaurant__isolated] candidates so far: 24
# [restaurant__isolated] candidates so far: 34
# [restaurant__isolated] candidates so far: 59
# [restaurant__isolated] final kept: 40 (time 5.7s)
# [buffer] built union buffer with 1100m
# [restaurant__small_cluster] candidates so far: 12
# [restaurant__small_cluster] OSM query failed near (40.0129752, -76.71924779999999): No matching features. Check query location, tags, and log.
# [restaurant__small_cluster] candidates so far: 28
# [restaurant__small_cluster] candidates so far: 43
# [restaurant__small_cluster] final kept: 30 (time 0.6s)
# [buffer] built union buffer with 1500m
# [restaurant__dense_cluster] candidates so far: 6
# [restaurant__dense_cluster] OSM query failed near (32.790974, -97.01603999999999): No matching features. Check query location, tags, and log.
# [restaurant__dense_cluster] candidates so far: 7
# [restaurant__dense_cluster] candidates so far: 17
# [restaurant__dense_cluster] candidates so far: 40
# [restaurant__dense_cluster] final kept: 30 (time 17.1s)
#
# [strategy=density_v1] category=hospital
# [buffer] built union buffer with 900m
# [hospital__isolated] candidates so far: 1
# [hospital__isolated] candidates so far: 2
# [hospital__isolated] candidates so far: 3
# [hospital__isolated] OSM query failed near (42.1127167, -71.4708436): No matching features. Check query location, tags, and log.
# [hospital__isolated] candidates so far: 6
# [hospital__isolated] candidates so far: 12
# [hospital__isolated] OSM query failed near (52.5278899, -0.300448): No matching features. Check query location, tags, and log.
# [hospital__isolated] OSM query failed near (35.9583737, -84.14550260000001): No matching features. Check query location, tags, and log.
# [hospital__isolated] candidates so far: 14
# [hospital__isolated] OSM query failed near (28.7145622, -81.59405509999999): No matching features. Check query location, tags, and log.
# [hospital__isolated] candidates so far: 15
# [hospital__isolated] OSM query failed near (38.944189, -95.019476): No matching features. Check query location, tags, and log.
# [hospital__isolated] candidates so far: 21
# [hospital__isolated] candidates so far: 22
# [hospital__isolated] OSM query failed near (42.0850507, -71.4600414): No matching features. Check query location, tags, and log.
# [hospital__isolated] candidates so far: 23
# [hospital__isolated] OSM query failed near (25.9549931, -97.4076254): No matching features. Check query location, tags, and log.
# [hospital__isolated] OSM query failed near (40.2060266, -79.62065919999999): No matching features. Check query location, tags, and log.
# [hospital__isolated] OSM query failed near (35.8187957, -80.97943339999999): No matching features. Check query location, tags, and log.
# [hospital__isolated] OSM query failed near (35.5868669, -80.8064361): No matching features. Check query location, tags, and log.
# [hospital__isolated] final kept: 23 (time 86.6s)
# [buffer] built union buffer with 1100m
# [hospital__small_cluster] OSM query failed near (35.4212494, -80.6631755): No matching features. Check query location, tags, and log.
# [hospital__small_cluster] OSM query failed near (40.0129752, -76.71924779999999): No matching features. Check query location, tags, and log.
# [hospital__small_cluster] OSM query failed near (47.2085859, -122.241051): No matching features. Check query location, tags, and log.
# [hospital__small_cluster] OSM query failed near (40.0483977, -76.3886708): No matching features. Check query location, tags, and log.
# [hospital__small_cluster] candidates so far: 1
# [hospital__small_cluster] OSM query failed near (41.2881194, -75.7422504): No matching features. Check query location, tags, and log.
# [hospital__small_cluster] candidates so far: 2
# [hospital__small_cluster] OSM query failed near (37.9997937, -122.3369357): No matching features. Check query location, tags, and log.
# [hospital__small_cluster] OSM query failed near (29.8043645, -95.27087879999999): No matching features. Check query location, tags, and log.
# [hospital__small_cluster] candidates so far: 8
# [hospital__small_cluster] candidates so far: 12
# [hospital__small_cluster] OSM query failed near (40.8605866, -74.3038603): No matching features. Check query location, tags, and log.
# [hospital__small_cluster] OSM query failed near (33.2790678, -111.8087505): No matching features. Check query location, tags, and log.
# [hospital__small_cluster] OSM query failed near (38.88692, -77.006344): No matching features. Check query location, tags, and log.
# [hospital__small_cluster] OSM query failed near (36.004783, -86.58301180000001): No matching features. Check query location, tags, and log.
# [hospital__small_cluster] final kept: 12 (time 2.2s)
# [buffer] built union buffer with 1500m
# [hospital__dense_cluster] OSM query failed near (43.8034093, -79.52085939999999): No matching features. Check query location, tags, and log.
# [hospital__dense_cluster] OSM query failed near (32.790974, -97.01603999999999): No matching features. Check query location, tags, and log.
# [hospital__dense_cluster] OSM query failed near (35.0287559, -89.9212184): No matching features. Check query location, tags, and log.
# [hospital__dense_cluster] OSM query failed near (32.9305457, -96.8348939): No matching features. Check query location, tags, and log.
# [hospital__dense_cluster] candidates so far: 1
# [hospital__dense_cluster] OSM query failed near (39.77926739999999, -104.8551571): No matching features. Check query location, tags, and log.
# [hospital__dense_cluster] OSM query failed near (33.9025764, -117.2853348): No matching features. Check query location, tags, and log.
# [hospital__dense_cluster] OSM query failed near (40.72913399999999, -111.9821665): No matching features. Check query location, tags, and log.
# [hospital__dense_cluster] OSM query failed near (39.78579269999999, -82.9367113): No matching features. Check query location, tags, and log.
# [hospital__dense_cluster] OSM query failed near (29.7798592, -95.43929829999999): No matching features. Check query location, tags, and log.
# [hospital__dense_cluster] OSM query failed near (33.9923262, -118.1594227): No matching features. Check query location, tags, and log.
# [hospital__dense_cluster] OSM query failed near (34.9260993, -90.0028931): No matching features. Check query location, tags, and log.
# [hospital__dense_cluster] OSM query failed near (32.8033265, -97.4358585): No matching features. Check query location, tags, and log.
# [hospital__dense_cluster] OSM query failed near (33.4171743, -112.0654639): No matching features. Check query location, tags, and log.
# [hospital__dense_cluster] final kept: 1 (time 100.0s)
#
# [strategy=density_v1] category=hotel
# [buffer] built union buffer with 900m
# [hotel__isolated] candidates so far: 9
# [hotel__isolated] candidates so far: 29
# [hotel__isolated] candidates so far: 30
# [hotel__isolated] candidates so far: 40
# [hotel__isolated] candidates so far: 41
# [hotel__isolated] candidates so far: 53
# [hotel__isolated] final kept: 40 (time 13.2s)
# [buffer] built union buffer with 1100m
# [hotel__small_cluster] candidates so far: 1
# [hotel__small_cluster] candidates so far: 2
# [hotel__small_cluster] OSM query failed near (47.2085859, -122.241051): No matching features. Check query location, tags, and log.
# [hotel__small_cluster] candidates so far: 5
# [hotel__small_cluster] candidates so far: 28
# [hotel__small_cluster] OSM query failed near (41.2881194, -75.7422504): No matching features. Check query location, tags, and log.
# [hotel__small_cluster] candidates so far: 30
# [hotel__small_cluster] candidates so far: 32
# [hotel__small_cluster] final kept: 30 (time 1.3s)
# [buffer] built union buffer with 1500m
# [hotel__dense_cluster] candidates so far: 4
# [hotel__dense_cluster] OSM query failed near (32.790974, -97.01603999999999): No matching features. Check query location, tags, and log.
# [hotel__dense_cluster] OSM query failed near (35.0287559, -89.9212184): No matching features. Check query location, tags, and log.
# [hotel__dense_cluster] candidates so far: 8
# [hotel__dense_cluster] candidates so far: 12
# [hotel__dense_cluster] candidates so far: 14
# [hotel__dense_cluster] OSM query failed near (40.72913399999999, -111.9821665): No matching features. Check query location, tags, and log.
# [hotel__dense_cluster] OSM query failed near (39.78579269999999, -82.9367113): No matching features. Check query location, tags, and log.
# [hotel__dense_cluster] candidates so far: 15
# [hotel__dense_cluster] candidates so far: 16
# [hotel__dense_cluster] OSM query failed near (33.4171743, -112.0654639): No matching features. Check query location, tags, and log.
# [hotel__dense_cluster] final kept: 16 (time 36.2s)
#
# [strategy=density_v1] category=supermarket
# [buffer] built union buffer with 900m
# [supermarket__isolated] candidates so far: 7
# [supermarket__isolated] OSM query failed near (29.4232747, -98.5972939): No matching features. Check query location, tags, and log.
# [supermarket__isolated] candidates so far: 14
# [supermarket__isolated] candidates so far: 18
# [supermarket__isolated] candidates so far: 35
# [supermarket__isolated] candidates so far: 40
# [supermarket__isolated] candidates so far: 52
# [supermarket__isolated] final kept: 40 (time 12.0s)
# [buffer] built union buffer with 1100m
# [supermarket__small_cluster] candidates so far: 3
# [supermarket__small_cluster] OSM query failed near (40.0129752, -76.71924779999999): No matching features. Check query location, tags, and log.
# [supermarket__small_cluster] candidates so far: 4
# [supermarket__small_cluster] candidates so far: 7
# [supermarket__small_cluster] candidates so far: 9
# [supermarket__small_cluster] OSM query failed near (41.2881194, -75.7422504): No matching features. Check query location, tags, and log.
# [supermarket__small_cluster] OSM query failed near (29.705843, -95.086879): No matching features. Check query location, tags, and log.
# [supermarket__small_cluster] candidates so far: 10
# [supermarket__small_cluster] OSM query failed near (29.8043645, -95.27087879999999): No matching features. Check query location, tags, and log.
# [supermarket__small_cluster] candidates so far: 32
# [supermarket__small_cluster] final kept: 30 (time 1.6s)
# [buffer] built union buffer with 1500m
# [supermarket__dense_cluster] candidates so far: 2
# [supermarket__dense_cluster] OSM query failed near (32.790974, -97.01603999999999): No matching features. Check query location, tags, and log.
# [supermarket__dense_cluster] OSM query failed near (35.0287559, -89.9212184): No matching features. Check query location, tags, and log.
# [supermarket__dense_cluster] candidates so far: 5
# [supermarket__dense_cluster] OSM query failed near (39.77926739999999, -104.8551571): No matching features. Check query location, tags, and log.
# [supermarket__dense_cluster] OSM query failed near (33.9025764, -117.2853348): No matching features. Check query location, tags, and log.
# [supermarket__dense_cluster] OSM query failed near (40.72913399999999, -111.9821665): No matching features. Check query location, tags, and log.
# [supermarket__dense_cluster] OSM query failed near (39.78579269999999, -82.9367113): No matching features. Check query location, tags, and log.
# [supermarket__dense_cluster] OSM query failed near (34.0003199, -118.219265): No matching features. Check query location, tags, and log.
# [supermarket__dense_cluster] OSM query failed near (29.7798592, -95.43929829999999): No matching features. Check query location, tags, and log.
# [supermarket__dense_cluster] OSM query failed near (33.9923262, -118.1594227): No matching features. Check query location, tags, and log.
# [supermarket__dense_cluster] OSM query failed near (34.9260993, -90.0028931): No matching features. Check query location, tags, and log.
# [supermarket__dense_cluster] candidates so far: 9
# [supermarket__dense_cluster] OSM query failed near (33.4171743, -112.0654639): No matching features. Check query location, tags, and log.
# [supermarket__dense_cluster] final kept: 9 (time 30.0s)
#
# [strategy=density_v1] category=school
# [buffer] built union buffer with 900m
# [school__isolated] candidates so far: 17
# [school__isolated] candidates so far: 46
# [school__isolated] final kept: 40 (time 9.0s)
# [buffer] built union buffer with 1100m
# [school__small_cluster] candidates so far: 4
# [school__small_cluster] candidates so far: 9
# [school__small_cluster] candidates so far: 16
# [school__small_cluster] candidates so far: 20
# [school__small_cluster] candidates so far: 29
# [school__small_cluster] candidates so far: 30
# [school__small_cluster] candidates so far: 31
# [school__small_cluster] candidates so far: 38
# [school__small_cluster] final kept: 30 (time 5.8s)
# [buffer] built union buffer with 1500m
# [school__dense_cluster] OSM query failed near (43.8034093, -79.52085939999999): No matching features. Check query location, tags, and log.
# [school__dense_cluster] OSM query failed near (35.0287559, -89.9212184): No matching features. Check query location, tags, and log.
# [school__dense_cluster] candidates so far: 5
# [school__dense_cluster] candidates so far: 9
# [school__dense_cluster] candidates so far: 10
# [school__dense_cluster] candidates so far: 11
# [school__dense_cluster] OSM query failed near (39.78579269999999, -82.9367113): No matching features. Check query location, tags, and log.
# [school__dense_cluster] candidates so far: 13
# [school__dense_cluster] candidates so far: 14
# [school__dense_cluster] OSM query failed near (34.9260993, -90.0028931): No matching features. Check query location, tags, and log.
# [school__dense_cluster] candidates so far: 19
# [school__dense_cluster] final kept: 19 (time 43.7s)
#
# [strategy=density_v1] category=park
# [buffer] built union buffer with 900m
# [park__isolated] candidates so far: 4
# [park__isolated] candidates so far: 24
# [park__isolated] candidates so far: 60
# [park__isolated] final kept: 40 (time 6.3s)
# [buffer] built union buffer with 1100m
# [park__small_cluster] candidates so far: 7
# [park__small_cluster] candidates so far: 10
# [park__small_cluster] candidates so far: 19
# [park__small_cluster] candidates so far: 25
# [park__small_cluster] candidates so far: 32
# [park__small_cluster] final kept: 30 (time 0.8s)
# [buffer] built union buffer with 1500m
# [park__dense_cluster] OSM query failed near (43.8034093, -79.52085939999999): No matching features. Check query location, tags, and log.
# [park__dense_cluster] OSM query failed near (35.0287559, -89.9212184): No matching features. Check query location, tags, and log.
# [park__dense_cluster] candidates so far: 3
# [park__dense_cluster] candidates so far: 17
# [park__dense_cluster] candidates so far: 18
# [park__dense_cluster] OSM query failed near (40.72913399999999, -111.9821665): No matching features. Check query location, tags, and log.
# [park__dense_cluster] OSM query failed near (39.78579269999999, -82.9367113): No matching features. Check query location, tags, and log.
# [park__dense_cluster] candidates so far: 24
# [park__dense_cluster] candidates so far: 25
# [park__dense_cluster] candidates so far: 30
# [park__dense_cluster] candidates so far: 36
# [park__dense_cluster] final kept: 30 (time 32.2s)
#
# [strategy=density_v1] category=playground
# [buffer] built union buffer with 900m
# [playground__isolated] candidates so far: 26
# [playground__isolated] candidates so far: 52
# [playground__isolated] final kept: 40 (time 6.0s)
# [buffer] built union buffer with 1100m
# [playground__small_cluster] candidates so far: 20
# [playground__small_cluster] candidates so far: 29
# [playground__small_cluster] candidates so far: 57
# [playground__small_cluster] final kept: 30 (time 0.5s)
# [buffer] built union buffer with 1500m
# [playground__dense_cluster] OSM query failed near (43.8034093, -79.52085939999999): No matching features. Check query location, tags, and log.
# [playground__dense_cluster] candidates so far: 1
# [playground__dense_cluster] OSM query failed near (35.0287559, -89.9212184): No matching features. Check query location, tags, and log.
# [playground__dense_cluster] candidates so far: 3
# [playground__dense_cluster] candidates so far: 30
# [playground__dense_cluster] OSM query failed near (33.9025764, -117.2853348): No matching features. Check query location, tags, and log.
# [playground__dense_cluster] candidates so far: 31
# [playground__dense_cluster] OSM query failed near (39.78579269999999, -82.9367113): No matching features. Check query location, tags, and log.
# [playground__dense_cluster] OSM query failed near (34.0003199, -118.219265): No matching features. Check query location, tags, and log.
# [playground__dense_cluster] candidates so far: 32
# [playground__dense_cluster] final kept: 30 (time 24.7s)
#
# [strategy=density_v1] category=sports_centre
# [buffer] built union buffer with 900m
# [sports_centre__isolated] candidates so far: 10
# [sports_centre__isolated] candidates so far: 14
# [sports_centre__isolated] candidates so far: 18
# [sports_centre__isolated] candidates so far: 20
# [sports_centre__isolated] candidates so far: 26
# [sports_centre__isolated] candidates so far: 30
# [sports_centre__isolated] candidates so far: 32
# [sports_centre__isolated] candidates so far: 38
# [sports_centre__isolated] candidates so far: 43
# [sports_centre__isolated] final kept: 40 (time 19.6s)
# [buffer] built union buffer with 1100m
# [sports_centre__small_cluster] candidates so far: 3
# [sports_centre__small_cluster] candidates so far: 4
# [sports_centre__small_cluster] candidates so far: 8
# [sports_centre__small_cluster] candidates so far: 10
# [sports_centre__small_cluster] candidates so far: 11
# [sports_centre__small_cluster] OSM query failed near (41.2881194, -75.7422504): No matching features. Check query location, tags, and log.
# [sports_centre__small_cluster] OSM query failed near (29.705843, -95.086879): No matching features. Check query location, tags, and log.
# [sports_centre__small_cluster] candidates so far: 14
# [sports_centre__small_cluster] candidates so far: 17
# [sports_centre__small_cluster] candidates so far: 41
# [sports_centre__small_cluster] final kept: 30 (time 1.6s)
# [buffer] built union buffer with 1500m
# [sports_centre__dense_cluster] candidates so far: 3
# [sports_centre__dense_cluster] OSM query failed near (32.790974, -97.01603999999999): No matching features. Check query location, tags, and log.
# [sports_centre__dense_cluster] OSM query failed near (35.0287559, -89.9212184): No matching features. Check query location, tags, and log.
# [sports_centre__dense_cluster] candidates so far: 5
# [sports_centre__dense_cluster] candidates so far: 8
# [sports_centre__dense_cluster] OSM query failed near (39.77926739999999, -104.8551571): No matching features. Check query location, tags, and log.
# [sports_centre__dense_cluster] OSM query failed near (33.9025764, -117.2853348): No matching features. Check query location, tags, and log.
# [sports_centre__dense_cluster] OSM query failed near (40.72913399999999, -111.9821665): No matching features. Check query location, tags, and log.
# [sports_centre__dense_cluster] OSM query failed near (39.78579269999999, -82.9367113): No matching features. Check query location, tags, and log.
# [sports_centre__dense_cluster] candidates so far: 9
# [sports_centre__dense_cluster] OSM query failed near (34.9260993, -90.0028931): No matching features. Check query location, tags, and log.
# [sports_centre__dense_cluster] OSM query failed near (32.8033265, -97.4358585): No matching features. Check query location, tags, and log.
# [sports_centre__dense_cluster] OSM query failed near (33.4171743, -112.0654639): No matching features. Check query location, tags, and log.
# [sports_centre__dense_cluster] final kept: 9 (time 35.9s)
#
# ======================================================================
# Running strategy: density_v2
# ======================================================================
#
# [strategy=density_v2] category=fuel
# [buffer] built union buffer with 800m
# [fuel__isolated] candidates so far: 18
# [fuel__isolated] candidates so far: 42
# [fuel__isolated] candidates so far: 56
# [fuel__isolated] final kept: 40 (time 5.8s)
# [buffer] built union buffer with 1200m
# [fuel__small_cluster] candidates so far: 7
# [fuel__small_cluster] candidates so far: 9
# [fuel__small_cluster] candidates so far: 16
# [fuel__small_cluster] candidates so far: 19
# [fuel__small_cluster] candidates so far: 32
# [fuel__small_cluster] final kept: 30 (time 13.5s)
# [buffer] built union buffer with 1600m
# [fuel__dense_cluster] candidates so far: 1
# [fuel__dense_cluster] candidates so far: 2
# [fuel__dense_cluster] candidates so far: 9
# [fuel__dense_cluster] candidates so far: 14
# [fuel__dense_cluster] candidates so far: 15
# [fuel__dense_cluster] OSM query failed near (39.78579269999999, -82.9367113): No matching features. Check query location, tags, and log.
# [fuel__dense_cluster] candidates so far: 18
# [fuel__dense_cluster] candidates so far: 20
# [fuel__dense_cluster] candidates so far: 22
# [fuel__dense_cluster] candidates so far: 23
# [fuel__dense_cluster] candidates so far: 29
# [fuel__dense_cluster] final kept: 29 (time 40.0s)
#
# [strategy=density_v2] category=parking
# [buffer] built union buffer with 800m
# [parking__isolated] candidates so far: 277
# [parking__isolated] final kept: 40 (time 2.3s)
# [buffer] built union buffer with 1200m
# [parking__small_cluster] candidates so far: 230
# [parking__small_cluster] final kept: 30 (time 7.2s)
# [buffer] built union buffer with 1600m
# [parking__dense_cluster] candidates so far: 171
# [parking__dense_cluster] final kept: 30 (time 1.9s)
#
# [strategy=density_v2] category=restaurant
# [buffer] built union buffer with 800m
# [restaurant__isolated] candidates so far: 25
# [restaurant__isolated] candidates so far: 55
# [restaurant__isolated] final kept: 40 (time 3.4s)
# [buffer] built union buffer with 1200m
# [restaurant__small_cluster] candidates so far: 10
# [restaurant__small_cluster] OSM query failed near (40.0129752, -76.71924779999999): No matching features. Check query location, tags, and log.
# [restaurant__small_cluster] candidates so far: 28
# [restaurant__small_cluster] candidates so far: 46
# [restaurant__small_cluster] final kept: 30 (time 8.2s)
# [buffer] built union buffer with 1600m
# [restaurant__dense_cluster] candidates so far: 10
# [restaurant__dense_cluster] OSM query failed near (32.790974, -97.01603999999999): No matching features. Check query location, tags, and log.
# [restaurant__dense_cluster] candidates so far: 11
# [restaurant__dense_cluster] candidates so far: 25
# [restaurant__dense_cluster] candidates so far: 105
# [restaurant__dense_cluster] final kept: 30 (time 11.3s)
#
# [strategy=density_v2] category=hospital
# [buffer] built union buffer with 800m
# [hospital__isolated] candidates so far: 1
# [hospital__isolated] candidates so far: 3
# [hospital__isolated] candidates so far: 5
# [hospital__isolated] candidates so far: 6
# [hospital__isolated] candidates so far: 11
# [hospital__isolated] candidates so far: 20
# [hospital__isolated] OSM query failed near (52.5278899, -0.300448): No matching features. Check query location, tags, and log.
# [hospital__isolated] candidates so far: 21
# [hospital__isolated] candidates so far: 23
# [hospital__isolated] OSM query failed near (28.7145622, -81.59405509999999): No matching features. Check query location, tags, and log.
# [hospital__isolated] candidates so far: 24
# [hospital__isolated] OSM query failed near (38.944189, -95.019476): No matching features. Check query location, tags, and log.
# [hospital__isolated] candidates so far: 31
# [hospital__isolated] candidates so far: 33
# [hospital__isolated] OSM query failed near (42.0850507, -71.4600414): No matching features. Check query location, tags, and log.
# [hospital__isolated] candidates so far: 34
# [hospital__isolated] OSM query failed near (25.9549931, -97.4076254): No matching features. Check query location, tags, and log.
# [hospital__isolated] OSM query failed near (40.2060266, -79.62065919999999): No matching features. Check query location, tags, and log.
# [hospital__isolated] OSM query failed near (35.8187957, -80.97943339999999): No matching features. Check query location, tags, and log.
# [hospital__isolated] candidates so far: 35
# [hospital__isolated] final kept: 35 (time 66.7s)
# [buffer] built union buffer with 1200m
# [hospital__small_cluster] OSM query failed near (35.4212494, -80.6631755): No matching features. Check query location, tags, and log.
# [hospital__small_cluster] OSM query failed near (40.0129752, -76.71924779999999): No matching features. Check query location, tags, and log.
# [hospital__small_cluster] OSM query failed near (47.2085859, -122.241051): No matching features. Check query location, tags, and log.
# ...
# [hospital__dense_cluster] OSM query failed near (39.78579269999999, -82.9367113): No matching features. Check query location, tags, and log.
# [hospital__dense_cluster] OSM query failed near (29.7798592, -95.43929829999999): No matching features. Check query location, tags, and log.
# [hospital__dense_cluster] OSM query failed near (33.9923262, -118.1594227): No matching features. Check query location, tags, and log.
# [hospital__dense_cluster] OSM query failed near (34.9260993, -90.0028931): No matching features. Check query location, tags, and log.
# [hospital__dense_cluster] OSM query failed near (32.8033265, -97.4358585): No matching features. Check query location, tags, and log.
# [hospital__dense_cluster] OSM query failed near (33.4171743, -112.0654639): No matching features. Check query location, tags, and log.
# [hospital__dense_cluster] final kept: 1 (time 56.4s)
#
# [strategy=density_v2] category=hotel
# [buffer] built union buffer with 800m
# [hotel__isolated] candidates so far: 9
# [hotel__isolated] candidates so far: 38
# [hotel__isolated] candidates so far: 39
# [hotel__isolated] candidates so far: 42
# [hotel__isolated] candidates so far: 54
# [hotel__isolated] final kept: 40 (time 15.8s)
# [buffer] built union buffer with 1200m
# [hotel__small_cluster] candidates so far: 1
# [hotel__small_cluster] candidates so far: 4
# [hotel__small_cluster] candidates so far: 6
# [hotel__small_cluster] candidates so far: 9
# [hotel__small_cluster] candidates so far: 34
# [hotel__small_cluster] final kept: 30 (time 9.5s)
# [buffer] built union buffer with 1600m
# [hotel__dense_cluster] candidates so far: 5
# [hotel__dense_cluster] OSM query failed near (32.790974, -97.01603999999999): No matching features. Check query location, tags, and log.
# [hotel__dense_cluster] OSM query failed near (35.0287559, -89.9212184): No matching features. Check query location, tags, and log.
# [hotel__dense_cluster] candidates so far: 12
# [hotel__dense_cluster] candidates so far: 22
# [hotel__dense_cluster] candidates so far: 24
# [hotel__dense_cluster] OSM query failed near (39.78579269999999, -82.9367113): No matching features. Check query location, tags, and log.
# [hotel__dense_cluster] candidates so far: 25
# [hotel__dense_cluster] candidates so far: 26
# [hotel__dense_cluster] candidates so far: 27
# [hotel__dense_cluster] OSM query failed near (33.4171743, -112.0654639): No matching features. Check query location, tags, and log.
# [hotel__dense_cluster] final kept: 27 (time 41.7s)
#
# [strategy=density_v2] category=supermarket
# [buffer] built union buffer with 800m
# [supermarket__isolated] candidates so far: 7
# [supermarket__isolated] candidates so far: 12
# [supermarket__isolated] candidates so far: 23
# [supermarket__isolated] candidates so far: 31
# [supermarket__isolated] candidates so far: 52
# [supermarket__isolated] final kept: 40 (time 13.6s)
# [buffer] built union buffer with 1200m
# [supermarket__small_cluster] candidates so far: 4
# [supermarket__small_cluster] OSM query failed near (40.0129752, -76.71924779999999): No matching features. Check query location, tags, and log.
# [supermarket__small_cluster] candidates so far: 7
# [supermarket__small_cluster] candidates so far: 14
# [supermarket__small_cluster] candidates so far: 16
# [supermarket__small_cluster] OSM query failed near (29.705843, -95.086879): No matching features. Check query location, tags, and log.
# [supermarket__small_cluster] candidates so far: 18
# [supermarket__small_cluster] OSM query failed near (29.8043645, -95.27087879999999): No matching features. Check query location, tags, and log.
# [supermarket__small_cluster] candidates so far: 46
# [supermarket__small_cluster] final kept: 30 (time 17.2s)
# [buffer] built union buffer with 1600m
# [supermarket__dense_cluster] candidates so far: 2
# [supermarket__dense_cluster] OSM query failed near (32.790974, -97.01603999999999): No matching features. Check query location, tags, and log.
# [supermarket__dense_cluster] OSM query failed near (35.0287559, -89.9212184): No matching features. Check query location, tags, and log.
# [supermarket__dense_cluster] candidates so far: 4
# [supermarket__dense_cluster] candidates so far: 8
# [supermarket__dense_cluster] OSM query failed near (39.77926739999999, -104.8551571): No matching features. Check query location, tags, and log.
# [supermarket__dense_cluster] OSM query failed near (33.9025764, -117.2853348): No matching features. Check query location, tags, and log.
# [supermarket__dense_cluster] OSM query failed near (40.72913399999999, -111.9821665): No matching features. Check query location, tags, and log.
# [supermarket__dense_cluster] OSM query failed near (39.78579269999999, -82.9367113): No matching features. Check query location, tags, and log.
# [supermarket__dense_cluster] candidates so far: 9
# [supermarket__dense_cluster] OSM query failed near (29.7798592, -95.43929829999999): No matching features. Check query location, tags, and log.
# [supermarket__dense_cluster] OSM query failed near (33.9923262, -118.1594227): No matching features. Check query location, tags, and log.
# [supermarket__dense_cluster] OSM query failed near (34.9260993, -90.0028931): No matching features. Check query location, tags, and log.
# [supermarket__dense_cluster] candidates so far: 11
# [supermarket__dense_cluster] OSM query failed near (33.4171743, -112.0654639): No matching features. Check query location, tags, and log.
# [supermarket__dense_cluster] final kept: 11 (time 26.1s)
#
# [strategy=density_v2] category=school
# [buffer] built union buffer with 800m
# [school__isolated] candidates so far: 17
# [school__isolated] candidates so far: 68
# [school__isolated] final kept: 40 (time 3.5s)
# [buffer] built union buffer with 1200m
# [school__small_cluster] candidates so far: 5
# [school__small_cluster] candidates so far: 13
# [school__small_cluster] candidates so far: 23
# [school__small_cluster] candidates so far: 27
# [school__small_cluster] candidates so far: 40
# [school__small_cluster] final kept: 30 (time 12.0s)
# [buffer] built union buffer with 1600m
# [school__dense_cluster] OSM query failed near (43.8034093, -79.52085939999999): No matching features. Check query location, tags, and log.
# [school__dense_cluster] OSM query failed near (35.0287559, -89.9212184): No matching features. Check query location, tags, and log.
# [school__dense_cluster] candidates so far: 5
# [school__dense_cluster] candidates so far: 16
# [school__dense_cluster] candidates so far: 17
# [school__dense_cluster] candidates so far: 18
# [school__dense_cluster] OSM query failed near (39.78579269999999, -82.9367113): No matching features. Check query location, tags, and log.
# [school__dense_cluster] candidates so far: 20
# [school__dense_cluster] candidates so far: 22
# [school__dense_cluster] candidates so far: 25
# [school__dense_cluster] OSM query failed near (34.9260993, -90.0028931): No matching features. Check query location, tags, and log.
# [school__dense_cluster] candidates so far: 26
# [school__dense_cluster] candidates so far: 35
# [school__dense_cluster] final kept: 30 (time 33.6s)
#
# [strategy=density_v2] category=park
# [buffer] built union buffer with 800m
# [park__isolated] candidates so far: 5
# [park__isolated] candidates so far: 37
# [park__isolated] candidates so far: 103
# [park__isolated] final kept: 40 (time 6.0s)
# [buffer] built union buffer with 1200m
# [park__small_cluster] candidates so far: 8
# [park__small_cluster] candidates so far: 13
# [park__small_cluster] candidates so far: 27
# [park__small_cluster] candidates so far: 38
# [park__small_cluster] final kept: 30 (time 7.5s)
# [buffer] built union buffer with 1600m
# [park__dense_cluster] candidates so far: 1
# [park__dense_cluster] OSM query failed near (35.0287559, -89.9212184): No matching features. Check query location, tags, and log.
# [park__dense_cluster] candidates so far: 4
# [park__dense_cluster] candidates so far: 30
# [park__dense_cluster] candidates so far: 34
# [park__dense_cluster] final kept: 30 (time 14.9s)
#
# [strategy=density_v2] category=playground
# [buffer] built union buffer with 800m
# [playground__isolated] candidates so far: 30
# [playground__isolated] candidates so far: 72
# [playground__isolated] final kept: 40 (time 3.6s)
# [buffer] built union buffer with 1200m
# [playground__small_cluster] candidates so far: 20
# [playground__small_cluster] candidates so far: 31
# [playground__small_cluster] candidates so far: 70
# [playground__small_cluster] final kept: 30 (time 5.5s)
# [buffer] built union buffer with 1600m
# [playground__dense_cluster] OSM query failed near (43.8034093, -79.52085939999999): No matching features. Check query location, tags, and log.
# [playground__dense_cluster] OSM query failed near (35.0287559, -89.9212184): No matching features. Check query location, tags, and log.
# [playground__dense_cluster] candidates so far: 7
# [playground__dense_cluster] candidates so far: 46
# [playground__dense_cluster] final kept: 30 (time 9.2s)
#
# [strategy=density_v2] category=sports_centre
# [buffer] built union buffer with 800m
# [sports_centre__isolated] candidates so far: 11
# [sports_centre__isolated] candidates so far: 16
# [sports_centre__isolated] candidates so far: 23
# [sports_centre__isolated] candidates so far: 25
# [sports_centre__isolated] candidates so far: 36
# [sports_centre__isolated] candidates so far: 43
# [sports_centre__isolated] final kept: 40 (time 11.1s)
# [buffer] built union buffer with 1200m
# [sports_centre__small_cluster] candidates so far: 4
# [sports_centre__small_cluster] candidates so far: 5
# [sports_centre__small_cluster] candidates so far: 10
# [sports_centre__small_cluster] candidates so far: 12
# [sports_centre__small_cluster] candidates so far: 13
# [sports_centre__small_cluster] OSM query failed near (41.2881194, -75.7422504): No matching features. Check query location, tags, and log.
# [sports_centre__small_cluster] candidates so far: 15
# [sports_centre__small_cluster] candidates so far: 18
# [sports_centre__small_cluster] candidates so far: 21
# [sports_centre__small_cluster] candidates so far: 50
# [sports_centre__small_cluster] final kept: 30 (time 26.6s)
# [buffer] built union buffer with 1600m
# [sports_centre__dense_cluster] candidates so far: 4
# [sports_centre__dense_cluster] OSM query failed near (32.790974, -97.01603999999999): No matching features. Check query location, tags, and log.
# [sports_centre__dense_cluster] OSM query failed near (35.0287559, -89.9212184): No matching features. Check query location, tags, and log.
# [sports_centre__dense_cluster] candidates so far: 8
# [sports_centre__dense_cluster] candidates so far: 14
# [sports_centre__dense_cluster] OSM query failed near (39.77926739999999, -104.8551571): No matching features. Check query location, tags, and log.
# [sports_centre__dense_cluster] OSM query failed near (33.9025764, -117.2853348): No matching features. Check query location, tags, and log.
# [sports_centre__dense_cluster] OSM query failed near (40.72913399999999, -111.9821665): No matching features. Check query location, tags, and log.
# [sports_centre__dense_cluster] OSM query failed near (39.78579269999999, -82.9367113): No matching features. Check query location, tags, and log.
# [sports_centre__dense_cluster] OSM query failed near (34.9260993, -90.0028931): No matching features. Check query location, tags, and log.
# [sports_centre__dense_cluster] OSM query failed near (32.8033265, -97.4358585): No matching features. Check query location, tags, and log.
# [sports_centre__dense_cluster] OSM query failed near (33.4171743, -112.0654639): No matching features. Check query location, tags, and log.
# [sports_centre__dense_cluster] final kept: 14 (time 25.2s)
#
# === Strategy summary ===
#      strategy_name  n_categories  total_final_negatives  mean_per_category  \
# 2       density_v2            10                    913               91.3
# 0  baseline_global            10                    899               89.9
# 1       density_v1            10                    859               85.9
#
#    median_per_category  total_runtime_sec
# 2                 99.5         572.643451
# 0                100.0        1058.618891
# 1                 89.5         573.213276
#
# === Diagnostics sample ===
#        category   density_type  n_pos_available  n_seed_used  search_dist  \
# 0          fuel       isolated             2070           20         2500
# 1          fuel  small_cluster             1138           15         2500
# 2          fuel  dense_cluster              997           15         2500
# 3       parking       isolated             2070           20         2500
# 4       parking  small_cluster             1138           15         2500
# 5       parking  dense_cluster              997           15         2500
# 6    restaurant       isolated             2070           20         2500
# 7    restaurant  small_cluster             1138           15         2500
# 8    restaurant  dense_cluster              997           15         2500
# 9      hospital       isolated             2070           20         2500
# 10     hospital  small_cluster             1138           15         2500
# 11     hospital  dense_cluster              997           15         2500
# 12        hotel       isolated             2070           20         2500
# 13        hotel  small_cluster             1138           15         2500
# 14        hotel  dense_cluster              997           15         2500
# 15  supermarket       isolated             2070           20         2500
# 16  supermarket  small_cluster             1138           15         2500
# 17  supermarket  dense_cluster              997           15         2500
# 18       school       isolated             2070           20         2500
# 19       school  small_cluster             1138           15         2500
#
#     exclusion_buffer  n_candidates_kept    strategy_name  \
# 0               1000                 40  baseline_global
# 1               1000                 30  baseline_global
# 2               1000                 30  baseline_global
# 3               1000                 40  baseline_global
# 4               1000                 30  baseline_global
# 5               1000                 30  baseline_global
# 6               1000                 40  baseline_global
# 7               1000                 30  baseline_global
# 8               1000                 30  baseline_global
# 9               1000                 10  baseline_global
# 10              1000                 12  baseline_global
# 11              1000                  8  baseline_global
# 12              1000                 29  baseline_global
# 13              1000                 30  baseline_global
# 14              1000                 30  baseline_global
# 15              1000                 40  baseline_global
# 16              1000                 30  baseline_global
# 17              1000                 30  baseline_global
# 18              1000                 40  baseline_global
# 19              1000                 30  baseline_global
#
#     category_total_final_kept  category_seconds
# 0                         100         56.559327
# 1                         100         56.559327
# 2                         100         56.559327
# 3                         100         13.259759
# 4                         100         13.259759
# 5                         100         13.259759
# 6                         100         26.892899
# 7                         100         26.892899
# 8                         100         26.892899
# 9                          30        102.805922
# 10                         30        102.805922
# 11                         30        102.805922
# 12                         89         84.109292
# 13                         89         84.109292
# 14                         89         84.109292
# 15                        100        263.307068
# 16                        100        263.307068
# 17                        100        263.307068
# 18                        100        125.785366
# 19                        100        125.785366

# %%
# Saving results to csv files
for strategy_name, result in all_strategy_results.items():
    if result["neg_gdf"] is not None:
        result["neg_gdf"].drop(columns="geometry").to_csv(
            os.path.join(BASE_DIR, f"neg_{strategy_name}.csv"), index=False
        )

strategy_summary_df.to_csv(os.path.join(BASE_DIR, "strategy_summary.csv"), index=False)
strategy_diag_df.to_csv(os.path.join(BASE_DIR, "strategy_diag.csv"), index=False)

# %%
# Adding more images, runs only for deficient (strategy, category) pairs

# Load existing CSV
BASE_DIR = "/content/kmls_cleaned"

df_v2 = pd.read_csv(os.path.join(BASE_DIR, "neg_density_v2.csv"))
df_bg = pd.read_csv(os.path.join(BASE_DIR, "neg_baseline_global.csv"))

print("Loaded density_v2:", len(df_v2))
print("Loaded baseline_global:", len(df_bg))

# Define what needs topping up
N_TARGET = 100

def compute_gaps(df, strategy_name):
    counts = df.groupby("neg_category").size()
    gaps = {}
    for cat, cnt in counts.items():
        if cnt < N_TARGET:
            gaps[cat] = N_TARGET - cnt
    return gaps

gaps_v2 = compute_gaps(df_v2, "density_v2")
gaps_bg = compute_gaps(df_bg, "baseline_global")

print("\nGaps in density_v2:",  gaps_v2)
print("Gaps in baseline_global:", gaps_bg)

# Expanded tag sets (hospital gets clinic + doctors)
TOPUP_TAGS = {
    "hospital": [{"amenity": "hospital"}, {"amenity": "clinic"}, {"amenity": "doctors"}],
    "fuel": [{"amenity": "fuel"}],
    "hotel": [{"tourism": "hotel"}, {"tourism": "motel"}, {"tourism": "guest_house"}],
    "supermarket": [{"shop": "supermarket"}, {"shop": "wholesale"}],
    "sports_centre": [{"leisure": "sports_centre"}, {"leisure": "stadium"}, {"leisure": "fitness_centre"}],
    "parking": [{"amenity": "parking"}],
    "restaurant": [{"amenity": "restaurant"}],
    "school": [{"amenity": "school"}],
    "park": [{"leisure": "park"}],
    "playground": [{"leisure": "playground"}],
}

# Top-up sampling params per strategy
# Use slightly relaxed params vs. original to maximise yield
TOPUP_PARAMS = {
    "density_v2": {
        # use a flat generous setting for top-up queries
        "search_dist": 6000,
        "exclusion_buffer": 800,
        "n_seed": 40,
    },
    "baseline_global": {
        "search_dist": 4000,
        "exclusion_buffer": 1000,
        "n_seed": 40,
    },
}

def build_exclusion_union(pos_gdf_wgs84, buffer_m):
    pos_m = pos_gdf_wgs84.to_crs(epsg=3857)
    return unary_union(pos_m.geometry.buffer(buffer_m))

def query_osm_multi_tags(center, tag_list, dist):
    """Query OSM with multiple tag dicts, union results."""
    frames = []
    for tags in tag_list:
        try:
            gdf = ox.features_from_point(center, tags=tags, dist=dist)
            if gdf is not None and len(gdf) > 0:
                frames.append(gdf.reset_index())
        except Exception as e:
            print(f"  [OSM] tags={tags} near {center}: {e}")
    if not frames:
        return None
    out = pd.concat(frames, ignore_index=True)
    return out

def topup_category(
    existing_df, # existing negatives for this category (filtered)
    pos_gdf_wgs84, # all positive points (GeoDataFrame, EPSG:4326)
    category_name,
    tag_list,
    n_need, # how many more we need
    search_dist,
    exclusion_buffer,
    n_seed,
    strategy_name,
    random_state=42,
):
    """
    Sample seed positives, query OSM with expanded tags, filter,
    deduplicate against existing negatives, return top-up rows.
    """
    rng = random.Random(random_state)
    np.random.seed(random_state)

    # Build exclusion union from ALL positives
    pos_buffer_union = build_exclusion_union(pos_gdf_wgs84, exclusion_buffer)

    # Existing coord keys to avoid duplicates
    existing_keys = set(
        zip(existing_df["lat"].round(6), existing_df["lon"].round(6))
    ) if len(existing_df) > 0 else set()

    seed_idx = list(pos_gdf_wgs84.index)
    rng.shuffle(seed_idx)
    seed_idx = seed_idx[:n_seed]

    collected, seen = [], set(existing_keys)

    for idx in seed_idx:
        row = pos_gdf_wgs84.loc[idx]
        center = (float(row["lat"]), float(row["lon"]))

        raw = query_osm_multi_tags(center, tag_list, dist=search_dist)
        if raw is None or len(raw) == 0:
            continue

        raw = raw[raw.geometry.notnull()].copy()
        raw["geometry"] = raw["geometry"].apply(to_point_geometry)
        raw = raw[raw.geometry.notnull()].copy()
        if len(raw) == 0:
            continue

        gdf = gpd.GeoDataFrame(raw, geometry="geometry", crs="EPSG:4326")
        gdf["lon"] = gdf.geometry.x
        gdf["lat"] = gdf.geometry.y
        gdf = gdf.dropna(subset=["lat", "lon"]).copy()

        # Filter inside exclusion buffer
        gdf_m = gdf.to_crs(epsg=3857)
        gdf_m = gdf_m[~gdf_m.geometry.within(pos_buffer_union)].copy()
        if len(gdf_m) == 0:
            continue
        gdf = gdf_m.to_crs(epsg=4326)
        gdf["lon"] = gdf.geometry.x
        gdf["lat"] = gdf.geometry.y

        # Deduplicate
        gdf["coord_key"] = list(zip(gdf["lat"].round(6), gdf["lon"].round(6)))
        gdf = gdf[~gdf["coord_key"].isin(seen)].copy()
        seen.update(gdf["coord_key"].tolist())
        if len(gdf) == 0:
            continue

        collected.append(gdf[["lat", "lon"]].copy())
        total = sum(len(x) for x in collected)
        print(f"  [{category_name}] candidates: {total}")
        if total >= n_need * 2:   # collect 2× then sample down
            break

    if not collected:
        print(f"  [{category_name}] no new candidates found")
        return pd.DataFrame()

    out = pd.concat(collected, ignore_index=True).drop_duplicates(["lat", "lon"])
    out = out.sample(n=min(n_need, len(out)), random_state=random_state).reset_index(drop=True)
    out["neg_category"] = category_name
    out["base_category"] = category_name
    out["strategy_name"] = strategy_name
    # Mark top-up rows with a flat density type and the params used
    out["seed_density_type"] = "topup"
    out["search_dist_used"] = search_dist
    out["exclusion_buffer_used"] = exclusion_buffer
    print(f"  [{category_name}] top-up kept: {len(out)}")
    return out

pos_gdf_wgs84 = pos_gdf

# Run top-ups
def run_topups(existing_df, gaps, strategy_name, pos_gdf_wgs84):
    params = TOPUP_PARAMS[strategy_name]
    new_rows = []

    for cat, n_need in gaps.items():
        print(f"\n── Topping up [{strategy_name}] {cat} (need +{n_need}) ──")
        existing_cat = existing_df[existing_df["neg_category"] == cat].copy()
        tag_list = TOPUP_TAGS.get(cat, [{"amenity": cat}])

        extra = topup_category(
            existing_df     = existing_cat,
            pos_gdf_wgs84   = pos_gdf_wgs84,
            category_name   = cat,
            tag_list        = tag_list,
            n_need          = n_need,
            search_dist     = params["search_dist"],
            exclusion_buffer= params["exclusion_buffer"],
            n_seed          = params["n_seed"],
            strategy_name   = strategy_name,
        )
        if len(extra) > 0:
            new_rows.append(extra)
        time.sleep(0.5)   # be polite to OSM

    if not new_rows:
        print(f"No top-ups produced for {strategy_name}")
        return existing_df

    # Merge and re-index
    combined = pd.concat([existing_df] + new_rows, ignore_index=True)
    combined = combined.drop_duplicates(subset=["lat", "lon"]).reset_index(drop=True)
    # Enforce N_TARGET cap per category
    combined = (
        combined.groupby("neg_category", group_keys=False)
        .apply(lambda g: g.head(N_TARGET))
        .reset_index(drop=True)
    )
    # Re-assign sample_id and image_name
    combined["sample_id"] = combined.index.astype(str).str.zfill(7)
    combined["image_name"] = "neg_" + combined["sample_id"] + ".png"
    return combined

df_v2_updated = run_topups(df_v2, gaps_v2, "density_v2", pos_gdf_wgs84)
df_bg_updated = run_topups(df_bg, gaps_bg, "baseline_global", pos_gdf_wgs84)

# Save updated CSVs
out_v2 = os.path.join(BASE_DIR, "neg_density_v2_filled.csv")
out_bg = os.path.join(BASE_DIR, "neg_baseline_global_filled.csv")

df_v2_updated.to_csv(out_v2, index=False)
df_bg_updated.to_csv(out_bg, index=False)

print("\n=== Final counts ===")
print("density_v2:")
print(df_v2_updated.groupby("neg_category").size().sort_index())
print("\nbaseline_global:")
print(df_bg_updated.groupby("neg_category").size().sort_index())
print(f"\nSaved: {out_v2}")
print(f"Saved: {out_bg}")
# Out:
# Loaded density_v2: 913
# Loaded baseline_global: 899
#
# Gaps in density_v2: {'fuel': 1, 'hospital': 48, 'hotel': 3, 'sports_centre': 16, 'supermarket': 19}
# Gaps in baseline_global: {'hospital': 70, 'hotel': 11, 'sports_centre': 20}
#
# ── Topping up [density_v2] fuel (need +1) ──
#   [fuel] candidates: 59
#   [fuel] top-up kept: 1
#
# ── Topping up [density_v2] hospital (need +48) ──
#   [OSM] tags={'amenity': 'hospital'} near (43.6605722, -79.65575299999999): No matching features. Check query location, tags, and log.
#   [hospital] candidates: 33
#   [hospital] candidates: 42
#   [OSM] tags={'amenity': 'hospital'} near (33.4325285, -88.55654779999999): No matching features. Check query location, tags, and log.
#   [OSM] tags={'amenity': 'clinic'} near (33.4325285, -88.55654779999999): No matching features. Check query location, tags, and log.
#   [OSM] tags={'amenity': 'doctors'} near (33.4325285, -88.55654779999999): No matching features. Check query location, tags, and log.
#   [hospital] candidates: 90
#   [hospital] candidates: 106
#   [hospital] top-up kept: 48
#
# ── Topping up [density_v2] hotel (need +3) ──
#   [hotel] candidates: 53
#   [hotel] top-up kept: 3
#
# ── Topping up [density_v2] sports_centre (need +16) ──
#   [sports_centre] candidates: 25
#   [sports_centre] candidates: 32
#   [sports_centre] top-up kept: 16
#
# ── Topping up [density_v2] supermarket (need +19) ──
#   [supermarket] candidates: 29
#   [supermarket] candidates: 43
#   [supermarket] top-up kept: 19
# /tmp/ipykernel_22228/747949569.py:205: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: g.head(N_TARGET))
# ── Topping up [baseline_global] hospital (need +70) ──
#   [OSM] tags={'amenity': 'hospital'} near (43.6605722, -79.65575299999999): No matching features. Check query location, tags, and log.
#   [OSM] tags={'amenity': 'doctors'} near (43.6605722, -79.65575299999999): No matching features. Check query location, tags, and log.
#   [hospital] candidates: 2
#   [hospital] candidates: 6
#   [OSM] tags={'amenity': 'hospital'} near (33.4325285, -88.55654779999999): No matching features. Check query location, tags, and log.
#   [OSM] tags={'amenity': 'clinic'} near (33.4325285, -88.55654779999999): No matching features. Check query location, tags, and log.
#   [OSM] tags={'amenity': 'doctors'} near (33.4325285, -88.55654779999999): No matching features. Check query location, tags, and log.
#   [hospital] candidates: 19
#   [OSM] tags={'amenity': 'hospital'} near (29.56187, -98.4201358): No matching features. Check query location, tags, and log.
#   [OSM] tags={'amenity': 'doctors'} near (29.56187, -98.4201358): No matching features. Check query location, tags, and log.
#   [hospital] candidates: 21
#   [hospital] candidates: 29
#   [OSM] tags={'amenity': 'hospital'} near (39.9719213, -86.4088609): No matching features. Check query location, tags, and log.
#   [OSM] tags={'amenity': 'clinic'} near (39.9719213, -86.4088609): No matching features. Check query location, tags, and log.
#   [OSM] tags={'amenity': 'doctors'} near (39.9719213, -86.4088609): No matching features. Check query location, tags, and log.
#   [hospital] candidates: 37
#   [hospital] candidates: 60
#   [OSM] tags={'amenity': 'hospital'} near (44.442213, -73.1279139): No matching features. Check query location, tags, and log.
#   [hospital] candidates: 74
#   [OSM] tags={'amenity': 'hospital'} near (28.0089534, -82.39911479999999): No matching features. Check query location, tags, and log.
#   [hospital] candidates: 78
#   [hospital] candidates: 90
#   [OSM] tags={'amenity': 'hospital'} near (41.6035543, -88.1124423): No matching features. Check query location, tags, and log.
#   [OSM] tags={'amenity': 'clinic'} near (41.6035543, -88.1124423): No matching features. Check query location, tags, and log.
#   [OSM] tags={'amenity': 'hospital'} near (45.96144510000001, -73.46883): No matching features. Check query location, tags, and log.
#   [OSM] tags={'amenity': 'clinic'} near (45.96144510000001, -73.46883): No matching features. Check query location, tags, and log.
#   [OSM] tags={'amenity': 'doctors'} near (45.96144510000001, -73.46883): No matching features. Check query location, tags, and log.
#   [OSM] tags={'amenity': 'clinic'} near (35.0432536, -89.9098755): No matching features. Check query location, tags, and log.
#   [hospital] candidates: 91
#   [hospital] candidates: 99
#   [OSM] tags={'amenity': 'hospital'} near (35.325314, -80.84194389999999): No matching features. Check query location, tags, and log.
#   [OSM] tags={'amenity': 'doctors'} near (35.325314, -80.84194389999999): No matching features. Check query location, tags, and log.
#   [hospital] candidates: 100
#   [OSM] tags={'amenity': 'hospital'} near (38.3469326, -121.9998261): No matching features. Check query location, tags, and log.
#   [OSM] tags={'amenity': 'doctors'} near (38.3469326, -121.9998261): No matching features. Check query location, tags, and log.
#   [hospital] candidates: 101
#   [OSM] tags={'amenity': 'hospital'} near (43.0165123, -83.00995189999999): No matching features. Check query location, tags, and log.
#   [OSM] tags={'amenity': 'clinic'} near (43.0165123, -83.00995189999999): No matching features. Check query location, tags, and log.
#   [OSM] tags={'amenity': 'doctors'} near (43.0165123, -83.00995189999999): No matching features. Check query location, tags, and log.
#   [hospital] candidates: 115
#   [hospital] candidates: 132
#   [hospital] candidates: 160
#   [hospital] top-up kept: 70
#
# ── Topping up [baseline_global] hotel (need +11) ──
#   [OSM] tags={'tourism': 'guest_house'} near (43.6605722, -79.65575299999999): No matching features. Check query location, tags, and log.
#   [hotel] candidates: 21
#   [OSM] tags={'tourism': 'guest_house'} near (27.1781254, -80.239189): No matching features. Check query location, tags, and log.
#   [hotel] candidates: 30
#   [hotel] top-up kept: 11
#
# ── Topping up [baseline_global] sports_centre (need +20) ──
#   [OSM] tags={'leisure': 'stadium'} near (43.6605722, -79.65575299999999): No matching features. Check query location, tags, and log.
#   [sports_centre] candidates: 7
#   [sports_centre] candidates: 12
#   [OSM] tags={'leisure': 'sports_centre'} near (33.4325285, -88.55654779999999): No matching features. Check query location, tags, and log.
#   [OSM] tags={'leisure': 'stadium'} near (33.4325285, -88.55654779999999): No matching features. Check query location, tags, and log.
#   [OSM] tags={'leisure': 'fitness_centre'} near (33.4325285, -88.55654779999999): No matching features. Check query location, tags, and log.
#   [sports_centre] candidates: 29
#   [sports_centre] candidates: 46
#   [sports_centre] top-up kept: 20
#
# === Final counts ===
# density_v2:
# neg_category
# fuel             100
# hospital         100
# hotel            100
# park             100
# parking          100
# playground       100
# restaurant       100
# school           100
# sports_centre    100
# supermarket      100
# dtype: int64
#
# baseline_global:
# neg_category
# fuel             100
# hospital         100
# hotel            100
# park             100
# parking          100
# playground       100
# restaurant       100
# school           100
# sports_centre    100
# supermarket      100
# dtype: int64
#
# Saved: /content/kmls_cleaned/neg_density_v2_filled.csv
# Saved: /content/kmls_cleaned/neg_baseline_global_filled.csv
# /tmp/ipykernel_22228/747949569.py:205: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: g.head(N_TARGET))

# %%
# ── Hard Negative Sampling ──
N_TARGET_PER_CAT = 100  # hard neg per category (same as soft neg)
N_SEED = 40
SEARCH_DIST = 4000  # flat param — same for both strategies
EXCL_BUFFER = 1000  # same exclusion buffer as baseline_global

HARD_NEG_TAGS = {
    "industrial": [{"landuse": "industrial"}],
    "factory": [{"building": "factory"}],
    "retail_large": [{"building": "retail"}],
    "commercial": [{"building": "commercial"}],
    "wholesale": [{"shop": "wholesale"}, {"shop": "doityourself"}],
}

def query_hard_neg(category_name, tag_list, pos_gdf, n_target,
                   n_seed, search_dist, excl_buffer, random_state=42):
    rng = random.Random(random_state)
    np.random.seed(random_state)

    pos_buffer_union = build_exclusion_union(pos_gdf, excl_buffer)

    seed_idx = list(pos_gdf.index)
    rng.shuffle(seed_idx)
    seed_idx = seed_idx[:n_seed]

    collected, seen = [], set()

    for idx in seed_idx:
        row    = pos_gdf.loc[idx]
        center = (float(row["lat"]), float(row["lon"]))

        frames = []
        for tags in tag_list:
            try:
                gdf = ox.features_from_point(center, tags=tags, dist=search_dist)
                if gdf is not None and len(gdf) > 0:
                    frames.append(gdf.reset_index())
            except Exception as e:
                print(f"  [OSM] {category_name} tags={tags}: {e}")

        if not frames: continue
        raw = pd.concat(frames, ignore_index=True)

        raw = raw[raw.geometry.notnull()].copy()
        raw["geometry"] = raw["geometry"].apply(to_point_geometry)
        raw = raw[raw.geometry.notnull()].copy()
        if len(raw) == 0: continue

        gdf = gpd.GeoDataFrame(raw, geometry="geometry", crs="EPSG:4326")
        gdf["lon"] = gdf.geometry.x
        gdf["lat"] = gdf.geometry.y
        gdf = gdf.dropna(subset=["lat", "lon"]).copy()

        gdf_m = gdf.to_crs(epsg=3857)
        gdf_m = gdf_m[~gdf_m.geometry.within(pos_buffer_union)].copy()
        if len(gdf_m) == 0: continue
        gdf = gdf_m.to_crs(epsg=4326)
        gdf["lon"] = gdf.geometry.x
        gdf["lat"] = gdf.geometry.y

        gdf["coord_key"] = list(zip(gdf["lat"].round(6), gdf["lon"].round(6)))
        gdf = gdf[~gdf["coord_key"].isin(seen)].copy()
        seen.update(gdf["coord_key"].tolist())
        if len(gdf) == 0: continue

        collected.append(gdf[["lat", "lon"]].copy())
        total = sum(len(x) for x in collected)
        print(f"  [{category_name}] candidates: {total}")
        if total >= n_target * 2: break

    if not collected:
        print(f"  [{category_name}] no candidates found")
        return pd.DataFrame()

    out = pd.concat(collected, ignore_index=True).drop_duplicates(["lat", "lon"])
    out = out.sample(n=min(n_target, len(out)), random_state=random_state).reset_index(drop=True)
    print(f"  [{category_name}] kept: {len(out)}")
    return out

# ── Run queries ──────────────────────────────────────────────────────────────
print("\n— Querying hard negatives from OSM ————————————————————")
hard_neg_parts = []

for cat_name, tag_list in HARD_NEG_TAGS.items():
    print(f"\n  Category: {cat_name}")
    result = query_hard_neg(
        category_name=cat_name,
        tag_list=tag_list,
        pos_gdf=pos_gdf,
        n_target=N_TARGET_PER_CAT,
        n_seed=N_SEED,
        search_dist=SEARCH_DIST,
        excl_buffer=EXCL_BUFFER,
        random_state=RANDOM_STATE,
    )
    if len(result) > 0:
        result["neg_category"] = cat_name
        result["base_category"] = cat_name
        hard_neg_parts.append(result)
    time.sleep(1)


# ── Append hard negs to both strategy CSVs ───────────────────────────────────

if not hard_neg_parts:
    print("No hard negatives found — check OSM connectivity")
else:
    hard_neg_df = pd.concat(hard_neg_parts, ignore_index=True)
    print(f"\nTotal hard negatives collected: {len(hard_neg_df)}")
    print(hard_neg_df["neg_category"].value_counts())

    for strategy_name, csv_path in [
        ("density_v2", os.path.join(BASE_DIR, "neg_density_v2_filled.csv")),
        ("baseline_global", os.path.join(BASE_DIR, "neg_baseline_global_filled.csv")),
    ]:
        existing = pd.read_csv(csv_path)

        # Tag hard neg rows
        hn = hard_neg_df.copy()
        hn["strategy_name"] = strategy_name
        hn["seed_density_type"] = "hard_negative"
        hn["search_dist_used"] = SEARCH_DIST
        hn["exclusion_buffer_used"] = EXCL_BUFFER

        # Deduplicate against existing coords
        existing_keys = set(zip(existing["lat"].round(6), existing["lon"].round(6)))
        hn["coord_key"] = list(zip(hn["lat"].round(6), hn["lon"].round(6)))
        hn = hn[~hn["coord_key"].isin(existing_keys)].drop(columns=["coord_key"])

        combined = pd.concat([existing, hn], ignore_index=True)
        combined["sample_id"] = combined.index.astype(str).str.zfill(7)
        combined["image_name"] = "neg_" + combined["sample_id"] + ".png"
        combined.to_csv(csv_path, index=False)

        print(f"\n[{strategy_name}] {len(existing)} → {len(combined)} (+{len(hn)} hard neg)")
        print(combined["neg_category"].value_counts().to_string())

    print("\nHard negatives appended to both CSVs.")
    print("Next: re-run YOLO prep cell with same paths — hard neg included automatically.")
# Out:
# — Querying hard negatives from OSM ————————————————————
#
#   Category: industrial
#   [industrial] candidates: 102
#   [industrial] candidates: 104
#   [industrial] candidates: 108
#   [industrial] candidates: 243
#   [industrial] kept: 100
#
#   Category: factory
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [factory] candidates: 5
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [OSM] factory tags={'building': 'factory'}: No matching features. Check query location, tags, and log.
#   [factory] kept: 5
#
#   Category: retail_large
#   [retail_large] candidates: 31
#   [retail_large] candidates: 76
#   [OSM] retail_large tags={'building': 'retail'}: No matching features. Check query location, tags, and log.
#   [retail_large] candidates: 82
#   [retail_large] candidates: 95
#   [retail_large] candidates: 279
#   [retail_large] kept: 100
#
#   Category: commercial
#   [commercial] candidates: 21
#   [commercial] candidates: 31
#   [commercial] candidates: 35
#   [commercial] candidates: 189
#   [commercial] candidates: 203
#   [commercial] kept: 100
#
#   Category: wholesale
#   [OSM] wholesale tags={'shop': 'wholesale'}: No matching features. Check query location, tags, and log.
#   [wholesale] candidates: 3
#   [wholesale] candidates: 6
#   [OSM] wholesale tags={'shop': 'wholesale'}: No matching features. Check query location, tags, and log.
#   [OSM] wholesale tags={'shop': 'doityourself'}: No matching features. Check query location, tags, and log.
#   [wholesale] candidates: 7
#   [OSM] wholesale tags={'shop': 'wholesale'}: No matching features. Check query location, tags, and log.
#   [wholesale] candidates: 8
#   [OSM] wholesale tags={'shop': 'wholesale'}: No matching features. Check query location, tags, and log.
#   [wholesale] candidates: 10
#   [OSM] wholesale tags={'shop': 'wholesale'}: No matching features. Check query location, tags, and log.
#   [OSM] wholesale tags={'shop': 'doityourself'}: No matching features. Check query location, tags, and log.
#   [wholesale] candidates: 14
#   [OSM] wholesale tags={'shop': 'wholesale'}: No matching features. Check query location, tags, and log.
#   [wholesale] candidates: 16
#   [wholesale] candidates: 21
#   [OSM] wholesale tags={'shop': 'wholesale'}: No matching features. Check query location, tags, and log.
#   [OSM] wholesale tags={'shop': 'doityourself'}: No matching features. Check query location, tags, and log.
#   [OSM] wholesale tags={'shop': 'wholesale'}: No matching features. Check query location, tags, and log.
#   [wholesale] candidates: 24
#   [OSM] wholesale tags={'shop': 'wholesale'}: No matching features. Check query location, tags, and log.
#   [OSM] wholesale tags={'shop': 'doityourself'}: No matching features. Check query location, tags, and log.
#   [OSM] wholesale tags={'shop': 'wholesale'}: No matching features. Check query location, tags, and log.
#   [OSM] wholesale tags={'shop': 'doityourself'}: No matching features. Check query location, tags, and log.
#   [OSM] wholesale tags={'shop': 'wholesale'}: No matching features. Check query location, tags, and log.
#   [wholesale] candidates: 25
#   [OSM] wholesale tags={'shop': 'wholesale'}: No matching features. Check query location, tags, and log.
#   [wholesale] candidates: 26
#   [wholesale] candidates: 32
#   [OSM] wholesale tags={'shop': 'wholesale'}: No matching features. Check query location, tags, and log.
#   [OSM] wholesale tags={'shop': 'doityourself'}: No matching features. Check query location, tags, and log.
#   [OSM] wholesale tags={'shop': 'wholesale'}: No matching features. Check query location, tags, and log.
#   [OSM] wholesale tags={'shop': 'doityourself'}: No matching features. Check query location, tags, and log.
#   [wholesale] candidates: 34
#   [wholesale] candidates: 35
#   [wholesale] candidates: 38
#   [OSM] wholesale tags={'shop': 'wholesale'}: No matching features. Check query location, tags, and log.
#   [OSM] wholesale tags={'shop': 'doityourself'}: No matching features. Check query location, tags, and log.
#   [OSM] wholesale tags={'shop': 'wholesale'}: No matching features. Check query location, tags, and log.
#   [OSM] wholesale tags={'shop': 'doityourself'}: No matching features. Check query location, tags, and log.
#   [OSM] wholesale tags={'shop': 'wholesale'}: No matching features. Check query location, tags, and log.
#   [OSM] wholesale tags={'shop': 'doityourself'}: No matching features. Check query location, tags, and log.
#   [wholesale] candidates: 40
#   [OSM] wholesale tags={'shop': 'wholesale'}: No matching features. Check query location, tags, and log.
#   [OSM] wholesale tags={'shop': 'doityourself'}: No matching features. Check query location, tags, and log.
#   [wholesale] candidates: 43
#   [OSM] wholesale tags={'shop': 'wholesale'}: No matching features. Check query location, tags, and log.
#   [wholesale] candidates: 44
#   [OSM] wholesale tags={'shop': 'wholesale'}: No matching features. Check query location, tags, and log.
#   [wholesale] candidates: 45
#   [OSM] wholesale tags={'shop': 'wholesale'}: No matching features. Check query location, tags, and log.
#   [OSM] wholesale tags={'shop': 'doityourself'}: No matching features. Check query location, tags, and log.
#   [wholesale] candidates: 49
#   [wholesale] candidates: 51
#   [wholesale] candidates: 55
#   [OSM] wholesale tags={'shop': 'wholesale'}: No matching features. Check query location, tags, and log.
#   [OSM] wholesale tags={'shop': 'doityourself'}: No matching features. Check query location, tags, and log.
#   [wholesale] candidates: 56
#   [OSM] wholesale tags={'shop': 'wholesale'}: No matching features. Check query location, tags, and log.
#   [wholesale] candidates: 57
#   [wholesale] candidates: 60
#   [wholesale] candidates: 67
#   [wholesale] kept: 67
#
# Total hard negatives collected: 372
# neg_category
# industrial      100
# retail_large    100
# commercial      100
# wholesale        67
# factory           5
# Name: count, dtype: int64
#
# [density_v2] 1000 → 1372 (+372 hard neg)
# neg_category
# fuel             100
# parking          100
# restaurant       100
# hospital         100
# hotel            100
# supermarket      100
# school           100
# park             100
# playground       100
# sports_centre    100
# industrial       100
# retail_large     100
# commercial       100
# wholesale         67
# factory            5
#
# [baseline_global] 1000 → 1372 (+372 hard neg)
# neg_category
# fuel             100
# parking          100
# restaurant       100
# hospital         100
# hotel            100
# supermarket      100
# school           100
# park             100
# playground       100
# sports_centre    100
# industrial       100
# retail_large     100
# commercial       100
# wholesale         67
# factory            5
#
# Hard negatives appended to both CSVs.
# Next: re-run YOLO prep cell with same paths — hard neg included automatically.

# %%
# Verify the files we need
REQUIRED = [
    "neg_density_v2_filled.csv",
    "neg_baseline_global_filled.csv",
    "positive_points_cleaned_dedup.csv",
]
for fname in REQUIRED:
    path = os.path.join(BASE_DIR, fname)
    assert os.path.exists(path), f"Missing: {path}"
    df_tmp = pd.read_csv(path)
    print(f"  ✓ {fname}  ({len(df_tmp):,} rows)")

# Check current wholesale/factory counts
print("\nCurrent wholesale/factory counts:")
for strategy in ["density_v2", "baseline_global"]:
    df = pd.read_csv(os.path.join(BASE_DIR, f"neg_{strategy}_filled.csv"))
    counts = df[df["neg_category"].isin(["wholesale","factory"])]["neg_category"].value_counts()
    print(f"  [{strategy}]")
    print(counts.to_string())
# Out:
#   ✓ neg_density_v2_filled.csv  (1,372 rows)
#   ✓ neg_baseline_global_filled.csv  (1,372 rows)
#   ✓ positive_points_cleaned_dedup.csv  (4,205 rows)
#
# Current wholesale/factory counts:
#   [density_v2]
# neg_category
# wholesale    67
# factory       5
#   [baseline_global]
# neg_category
# wholesale    67
# factory       5

# %%
# ── Extended Top-Up: wholesale & factory only
# Appended to existing _filled.csv files — paths unchanged
print("=" * 60)
print("Extended Top-Up — wholesale & factory")
print("=" * 60)

EXTENDED_HARD_NEG_TAGS = {
    "wholesale": [
        {"shop": "wholesale"},
        {"shop": "doityourself"},
        {"shop": "cash_and_carry"},
        {"shop": "trade"},
    ],
    "factory": [
        {"building": "factory"},
        {"building": "industrial"},
        {"building": "manufacture"},
    ],
}

# Targets after extension
EXTENDED_TARGETS = {
    "wholesale": 150,
    "factory":   80,  # best effort, OSM density is low
}

SEARCH_DIST = 5000  # slightly wider than original 4000m
EXCL_BUFFER = 1000
N_SEED = 60  # more seeds to increase yield
pos_gdf_ext = pos_gdf

def extended_topup(existing_df, category, tag_list, n_target,
                   pos_gdf, search_dist, excl_buffer, n_seed,
                   random_state=42):
    """
    Top-up a single hard negative category using extended tags.
    Only queries for the gap between current count and n_target.
    Returns new rows only (to be appended).
    """
    current = existing_df[existing_df["neg_category"] == category]
    current_count = len(current)
    n_need = n_target - current_count

    print(f"\n  [{category}] current={current_count}, target={n_target}, need={n_need}")
    if n_need <= 0:
        print(f"  [{category}] already at target, skipping")
        return pd.DataFrame()

    # Build exclusion union
    pos_m = pos_gdf.to_crs(epsg=3857)
    pos_buffer_union = unary_union(pos_m.geometry.buffer(excl_buffer))

    # Existing coord keys to avoid duplicates
    existing_keys = set(zip(
        existing_df["lat"].round(6),
        existing_df["lon"].round(6)
    ))

    rng = random.Random(random_state)
    seed_idx = list(pos_gdf.index)
    rng.shuffle(seed_idx)
    seed_idx = seed_idx[:n_seed]

    collected, seen = [], set(existing_keys)

    for idx in seed_idx:
        row    = pos_gdf.loc[idx]
        center = (float(row["lat"]), float(row["lon"]))

        frames = []
        for tags in tag_list:
            try:
                gdf = ox.features_from_point(center, tags=tags, dist=search_dist)
                if gdf is not None and len(gdf) > 0:
                    frames.append(gdf.reset_index())
            except Exception as e:
                continue

        if not frames:
            continue

        raw = pd.concat(frames, ignore_index=True)
        raw = raw[raw.geometry.notnull()].copy()
        raw["geometry"] = raw["geometry"].apply(to_point_geometry)
        raw = raw[raw.geometry.notnull()].copy()
        if len(raw) == 0:
            continue

        gdf_f = gpd.GeoDataFrame(raw, geometry="geometry", crs="EPSG:4326")
        gdf_f["lon"] = gdf_f.geometry.x
        gdf_f["lat"] = gdf_f.geometry.y
        gdf_f = gdf_f.dropna(subset=["lat", "lon"]).copy()

        # Exclusion buffer filter
        gdf_m = gdf_f.to_crs(epsg=3857)
        gdf_m = gdf_m[~gdf_m.geometry.within(pos_buffer_union)].copy()
        if len(gdf_m) == 0:
            continue
        gdf_f = gdf_m.to_crs(epsg=4326)
        gdf_f["lon"] = gdf_f.geometry.x
        gdf_f["lat"] = gdf_f.geometry.y

        # Dedup
        gdf_f["coord_key"] = list(zip(gdf_f["lat"].round(6), gdf_f["lon"].round(6)))
        gdf_f = gdf_f[~gdf_f["coord_key"].isin(seen)].copy()
        seen.update(gdf_f["coord_key"].tolist())
        if len(gdf_f) == 0:
            continue

        collected.append(gdf_f[["lat", "lon"]].copy())
        total = sum(len(x) for x in collected)
        print(f"  [{category}] candidates so far: {total}")
        if total >= n_need * 2:
            break

    if not collected:
        print(f"  [{category}] no new candidates found")
        return pd.DataFrame()

    out = pd.concat(collected, ignore_index=True).drop_duplicates(["lat", "lon"])
    out = out.sample(n=min(n_need, len(out)), random_state=random_state).reset_index(drop=True)
    out["neg_category"] = category
    out["base_category"] = category
    out["seed_density_type"] = "hard_negative_extended"
    out["search_dist_used"] = search_dist
    out["exclusion_buffer_used"] = excl_buffer
    print(f"  [{category}] new rows to append: {len(out)}")
    return out

# Run for both strategy CSVs
for strategy_name in ["density_v2", "baseline_global"]:
    csv_path = os.path.join(BASE_DIR, f"neg_{strategy_name}_filled.csv")
    existing = pd.read_csv(csv_path)

    print(f"\n{'='*50}")
    print(f"Strategy: {strategy_name}")
    print(f"Current counts:")
    print(existing["neg_category"].value_counts().to_string())

    new_rows_all = []
    for category, tag_list in EXTENDED_HARD_NEG_TAGS.items():
        new_rows = extended_topup(
            existing_df=existing,
            category=category,
            tag_list=tag_list,
            n_target=EXTENDED_TARGETS[category],
            pos_gdf=pos_gdf_ext,
            search_dist=SEARCH_DIST,
            excl_buffer=EXCL_BUFFER,
            n_seed=N_SEED,
            random_state=RANDOM_STATE,
        )
        if len(new_rows) > 0:
            new_rows["strategy_name"] = strategy_name
            new_rows_all.append(new_rows)
        time.sleep(1)  # be polite to OSM

    if new_rows_all:
        combined = pd.concat([existing] + new_rows_all, ignore_index=True)
        combined = combined.drop_duplicates(subset=["lat", "lon"]).reset_index(drop=True)
        combined["sample_id"] = combined.index.astype(str).str.zfill(7)
        combined["image_name"] = "neg_" + combined["sample_id"] + ".png"
        combined.to_csv(csv_path, index=False)

        print(f"\n  [{strategy_name}] {len(existing)} → {len(combined)} rows")
        print(f"  Updated counts:")
        print(combined["neg_category"].value_counts().to_string())
    else:
        print(f"\n  [{strategy_name}] no new rows added")
# Out:
# ============================================================
# Extended Top-Up — wholesale & factory
# ============================================================
#
# ==================================================
# Strategy: density_v2
# Current counts:
# neg_category
# fuel             100
# parking          100
# restaurant       100
# hospital         100
# hotel            100
# supermarket      100
# school           100
# park             100
# playground       100
# sports_centre    100
# industrial       100
# retail_large     100
# commercial       100
# wholesale         67
# factory            5
#
#   [wholesale] current=67, target=150, need=83
#   [wholesale] candidates so far: 2
#   [wholesale] candidates so far: 7
#   [wholesale] candidates so far: 9
#   [wholesale] candidates so far: 11
#   [wholesale] candidates so far: 12
#   [wholesale] candidates so far: 13
#   [wholesale] candidates so far: 17
#   [wholesale] candidates so far: 19
#   [wholesale] candidates so far: 21
#   [wholesale] candidates so far: 24
#   [wholesale] candidates so far: 25
#   [wholesale] candidates so far: 31
#   [wholesale] candidates so far: 33
#   [wholesale] candidates so far: 59
#   [wholesale] candidates so far: 60
#   [wholesale] candidates so far: 62
#   [wholesale] candidates so far: 66
#   [wholesale] candidates so far: 74
#   [wholesale] candidates so far: 75
#   [wholesale] candidates so far: 76
#   [wholesale] candidates so far: 80
#   [wholesale] candidates so far: 81
#   [wholesale] candidates so far: 82
#   [wholesale] candidates so far: 84
#   [wholesale] candidates so far: 85
#   [wholesale] candidates so far: 87
#   [wholesale] candidates so far: 91
#   [wholesale] candidates so far: 93
#   [wholesale] candidates so far: 109
#   [wholesale] candidates so far: 113
#   [wholesale] candidates so far: 123
#   [wholesale] candidates so far: 127
#   [wholesale] candidates so far: 143
#   [wholesale] candidates so far: 145
#   [wholesale] candidates so far: 150
#   [wholesale] candidates so far: 152
#   [wholesale] candidates so far: 154
#   [wholesale] candidates so far: 155
#   [wholesale] candidates so far: 156
#   [wholesale] candidates so far: 161
#   [wholesale] candidates so far: 169
#   [wholesale] new rows to append: 83
#
#   [factory] current=5, target=80, need=75
#   [factory] candidates so far: 1104
#   [factory] new rows to append: 75
#
#   [density_v2] 1372 → 1528 rows
#   Updated counts:
# neg_category
# wholesale        148
# parking          100
# fuel             100
# hospital         100
# hotel            100
# supermarket      100
# restaurant       100
# school           100
# park             100
# sports_centre    100
# playground       100
# industrial       100
# retail_large     100
# commercial       100
# factory           80
#
# ==================================================
# Strategy: baseline_global
# Current counts:
# neg_category
# fuel             100
# parking          100
# restaurant       100
# hospital         100
# hotel            100
# supermarket      100
# school           100
# park             100
# playground       100
# sports_centre    100
# industrial       100
# retail_large     100
# commercial       100
# wholesale         67
# factory            5
#
#   [wholesale] current=67, target=150, need=83
#   [wholesale] candidates so far: 2
#   [wholesale] candidates so far: 7
#   [wholesale] candidates so far: 9
#   [wholesale] candidates so far: 11
#   [wholesale] candidates so far: 12
#   [wholesale] candidates so far: 13
#   [wholesale] candidates so far: 17
#   [wholesale] candidates so far: 19
#   [wholesale] candidates so far: 21
#   [wholesale] candidates so far: 24
#   [wholesale] candidates so far: 25
#   [wholesale] candidates so far: 31
#   [wholesale] candidates so far: 33
#   [wholesale] candidates so far: 59
#   [wholesale] candidates so far: 60
#   [wholesale] candidates so far: 62
#   [wholesale] candidates so far: 66
#   [wholesale] candidates so far: 74
#   [wholesale] candidates so far: 75
#   [wholesale] candidates so far: 76
#   [wholesale] candidates so far: 80
#   [wholesale] candidates so far: 81
#   [wholesale] candidates so far: 82
#   [wholesale] candidates so far: 84
#   [wholesale] candidates so far: 85
#   [wholesale] candidates so far: 87
#   [wholesale] candidates so far: 91
#   [wholesale] candidates so far: 93
#   [wholesale] candidates so far: 109
#   [wholesale] candidates so far: 113
#   [wholesale] candidates so far: 123
#   [wholesale] candidates so far: 127
#   [wholesale] candidates so far: 143
#   [wholesale] candidates so far: 145
#   [wholesale] candidates so far: 150
#   [wholesale] candidates so far: 152
#   [wholesale] candidates so far: 154
#   [wholesale] candidates so far: 155
#   [wholesale] candidates so far: 156
#   [wholesale] candidates so far: 161
#   [wholesale] candidates so far: 169
#   [wholesale] new rows to append: 83
#
#   [factory] current=5, target=80, need=75
#   [factory] candidates so far: 1104
#   [factory] new rows to append: 75
#
#   [baseline_global] 1372 → 1528 rows
#   Updated counts:
# neg_category
# wholesale        148
# parking          100
# fuel             100
# hospital         100
# hotel            100
# supermarket      100
# restaurant       100
# school           100
# park             100
# sports_centre    100
# playground       100
# industrial       100
# retail_large     100
# commercial       100
# factory           80

# %%
from google.colab import drive
drive.mount('/drive')

# Save all output to Drive for future use
for folder in ["kmls_cleaned", "dataset_build"]:
    src = f"/content/{folder}"
    dst = f"/drive/MyDrive/{folder}"
    if os.path.exists(src):
        if os.path.exists(dst):
            shutil.rmtree(dst)
        shutil.copytree(src, dst)
        print(f"Saved: {src} → {dst}")
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).
# Saved: /content/kmls_cleaned → /drive/MyDrive/kmls_cleaned
